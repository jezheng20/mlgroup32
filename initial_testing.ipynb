# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image

import numpy as np

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import os

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.models import Model

# load the ResNet50 Model
feature_extractor = ResNet50(weights='imagenet', include_top=False)
feature_extractor_new = Model(feature_extractor.input, feature_extractor.layers[-2].output)
feature_extractor_new.summary()

image_path = "Images/"

data_images = []

i = 0
for file in os.listdir(image_path):
    if i >= 1000:
        break
    path = image_path + file
    img = image.load_img(path, target_size=(90, 90))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    
    feature = feature_extractor_new.predict(img_data)
    feature_reshaped = np.array(feature).flatten()
    
    data_images.append(feature_reshaped)
    
    i+= 1
# Out:
# 2021-12-06 14:37:57.423505: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv1_pad (ZeroPadding2D)      (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  conv1_conv (Conv2D)            (None, None, None,   9472        ['conv1_pad[0][0]']
#                                 64)
#
#  conv1_bn (BatchNormalization)  (None, None, None,   256         ['conv1_conv[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['conv1_bn[0][0]']
#                                 64)
#
#  pool1_pad (ZeroPadding2D)      (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
#  pool1_pool (MaxPooling2D)      (None, None, None,   0           ['pool1_pad[0][0]']
#                                 64)
#
#  conv2_block1_1_conv (Conv2D)   (None, None, None,   4160        ['pool1_pool[0][0]']
#                                 64)
#
#  conv2_block1_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block1_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block1_1_relu (Activatio  (None, None, None,   0          ['conv2_block1_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block1_2_conv (Conv2D)   (None, None, None,   36928       ['conv2_block1_1_relu[0][0]']
#                                 64)
#
#  conv2_block1_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block1_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block1_2_relu (Activatio  (None, None, None,   0          ['conv2_block1_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block1_0_conv (Conv2D)   (None, None, None,   16640       ['pool1_pool[0][0]']
#                                 256)
#
#  conv2_block1_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block1_2_relu[0][0]']
#                                 256)
#
#  conv2_block1_0_bn (BatchNormal  (None, None, None,   1024       ['conv2_block1_0_conv[0][0]']
#  ization)                       256)
#
#  conv2_block1_3_bn (BatchNormal  (None, None, None,   1024       ['conv2_block1_3_conv[0][0]']
#  ization)                       256)
#
#  conv2_block1_add (Add)         (None, None, None,   0           ['conv2_block1_0_bn[0][0]',
#                                 256)                              'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, None, None,   0           ['conv2_block1_add[0][0]']
#                                 256)
#
#  conv2_block2_1_conv (Conv2D)   (None, None, None,   16448       ['conv2_block1_out[0][0]']
#                                 64)
#
#  conv2_block2_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block2_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block2_1_relu (Activatio  (None, None, None,   0          ['conv2_block2_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block2_2_conv (Conv2D)   (None, None, None,   36928       ['conv2_block2_1_relu[0][0]']
#                                 64)
#
#  conv2_block2_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block2_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block2_2_relu (Activatio  (None, None, None,   0          ['conv2_block2_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block2_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block2_2_relu[0][0]']
#                                 256)
#
#  conv2_block2_3_bn (BatchNormal  (None, None, None,   1024       ['conv2_block2_3_conv[0][0]']
#  ization)                       256)
#
#  conv2_block2_add (Add)         (None, None, None,   0           ['conv2_block1_out[0][0]',
#                                 256)                              'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, None, None,   0           ['conv2_block2_add[0][0]']
#                                 256)
#
#  conv2_block3_1_conv (Conv2D)   (None, None, None,   16448       ['conv2_block2_out[0][0]']
#                                 64)
#
#  conv2_block3_1_bn (BatchNormal  (None, None, None,   256        ['conv2_block3_1_conv[0][0]']
#  ization)                       64)
#
#  conv2_block3_1_relu (Activatio  (None, None, None,   0          ['conv2_block3_1_bn[0][0]']
#  n)                             64)
#
#  conv2_block3_2_conv (Conv2D)   (None, None, None,   36928       ['conv2_block3_1_relu[0][0]']
#                                 64)
#
#  conv2_block3_2_bn (BatchNormal  (None, None, None,   256        ['conv2_block3_2_conv[0][0]']
#  ization)                       64)
#
#  conv2_block3_2_relu (Activatio  (None, None, None,   0          ['conv2_block3_2_bn[0][0]']
#  n)                             64)
#
#  conv2_block3_3_conv (Conv2D)   (None, None, None,   16640       ['conv2_block3_2_relu[0][0]']
#                                 256)
#
#  conv2_block3_3_bn (BatchNormal  (None, None, None,   1024       ['conv2_block3_3_conv[0][0]']
#  ization)                       256)
#
#  conv2_block3_add (Add)         (None, None, None,   0           ['conv2_block2_out[0][0]',
#                                 256)                              'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, None, None,   0           ['conv2_block3_add[0][0]']
#                                 256)
#
#  conv3_block1_1_conv (Conv2D)   (None, None, None,   32896       ['conv2_block3_out[0][0]']
#                                 128)
#
#  conv3_block1_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block1_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block1_1_relu (Activatio  (None, None, None,   0          ['conv3_block1_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block1_1_relu[0][0]']
#                                 128)
#
#  conv3_block1_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block1_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block1_2_relu (Activatio  (None, None, None,   0          ['conv3_block1_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block1_0_conv (Conv2D)   (None, None, None,   131584      ['conv2_block3_out[0][0]']
#                                 512)
#
#  conv3_block1_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block1_2_relu[0][0]']
#                                 512)
#
#  conv3_block1_0_bn (BatchNormal  (None, None, None,   2048       ['conv3_block1_0_conv[0][0]']
#  ization)                       512)
#
#  conv3_block1_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block1_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block1_add (Add)         (None, None, None,   0           ['conv3_block1_0_bn[0][0]',
#                                 512)                              'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, None, None,   0           ['conv3_block1_add[0][0]']
#                                 512)
#
#  conv3_block2_1_conv (Conv2D)   (None, None, None,   65664       ['conv3_block1_out[0][0]']
#                                 128)
#
#  conv3_block2_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block2_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block2_1_relu (Activatio  (None, None, None,   0          ['conv3_block2_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block2_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block2_1_relu[0][0]']
#                                 128)
#
#  conv3_block2_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block2_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block2_2_relu (Activatio  (None, None, None,   0          ['conv3_block2_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block2_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block2_2_relu[0][0]']
#                                 512)
#
#  conv3_block2_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block2_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block2_add (Add)         (None, None, None,   0           ['conv3_block1_out[0][0]',
#                                 512)                              'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, None, None,   0           ['conv3_block2_add[0][0]']
#                                 512)
#
#  conv3_block3_1_conv (Conv2D)   (None, None, None,   65664       ['conv3_block2_out[0][0]']
#                                 128)
#
#  conv3_block3_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block3_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block3_1_relu (Activatio  (None, None, None,   0          ['conv3_block3_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block3_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block3_1_relu[0][0]']
#                                 128)
#
#  conv3_block3_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block3_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block3_2_relu (Activatio  (None, None, None,   0          ['conv3_block3_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block3_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block3_2_relu[0][0]']
#                                 512)
#
#  conv3_block3_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block3_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block3_add (Add)         (None, None, None,   0           ['conv3_block2_out[0][0]',
#                                 512)                              'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, None, None,   0           ['conv3_block3_add[0][0]']
#                                 512)
#
#  conv3_block4_1_conv (Conv2D)   (None, None, None,   65664       ['conv3_block3_out[0][0]']
#                                 128)
#
#  conv3_block4_1_bn (BatchNormal  (None, None, None,   512        ['conv3_block4_1_conv[0][0]']
#  ization)                       128)
#
#  conv3_block4_1_relu (Activatio  (None, None, None,   0          ['conv3_block4_1_bn[0][0]']
#  n)                             128)
#
#  conv3_block4_2_conv (Conv2D)   (None, None, None,   147584      ['conv3_block4_1_relu[0][0]']
#                                 128)
#
#  conv3_block4_2_bn (BatchNormal  (None, None, None,   512        ['conv3_block4_2_conv[0][0]']
#  ization)                       128)
#
#  conv3_block4_2_relu (Activatio  (None, None, None,   0          ['conv3_block4_2_bn[0][0]']
#  n)                             128)
#
#  conv3_block4_3_conv (Conv2D)   (None, None, None,   66048       ['conv3_block4_2_relu[0][0]']
#                                 512)
#
#  conv3_block4_3_bn (BatchNormal  (None, None, None,   2048       ['conv3_block4_3_conv[0][0]']
#  ization)                       512)
#
#  conv3_block4_add (Add)         (None, None, None,   0           ['conv3_block3_out[0][0]',
#                                 512)                              'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, None, None,   0           ['conv3_block4_add[0][0]']
#                                 512)
#
#  conv4_block1_1_conv (Conv2D)   (None, None, None,   131328      ['conv3_block4_out[0][0]']
#                                 256)
#
#  conv4_block1_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block1_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block1_1_relu (Activatio  (None, None, None,   0          ['conv4_block1_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block1_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block1_1_relu[0][0]']
#                                 256)
#
#  conv4_block1_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block1_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block1_2_relu (Activatio  (None, None, None,   0          ['conv4_block1_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block1_0_conv (Conv2D)   (None, None, None,   525312      ['conv3_block4_out[0][0]']
#                                 1024)
#
#  conv4_block1_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block1_2_relu[0][0]']
#                                 1024)
#
#  conv4_block1_0_bn (BatchNormal  (None, None, None,   4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block1_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block1_add (Add)         (None, None, None,   0           ['conv4_block1_0_bn[0][0]',
#                                 1024)                             'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, None, None,   0           ['conv4_block1_add[0][0]']
#                                 1024)
#
#  conv4_block2_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block1_out[0][0]']
#                                 256)
#
#  conv4_block2_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block2_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block2_1_relu (Activatio  (None, None, None,   0          ['conv4_block2_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block2_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block2_1_relu[0][0]']
#                                 256)
#
#  conv4_block2_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block2_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block2_2_relu (Activatio  (None, None, None,   0          ['conv4_block2_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block2_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block2_2_relu[0][0]']
#                                 1024)
#
#  conv4_block2_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block2_add (Add)         (None, None, None,   0           ['conv4_block1_out[0][0]',
#                                 1024)                             'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, None, None,   0           ['conv4_block2_add[0][0]']
#                                 1024)
#
#  conv4_block3_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block2_out[0][0]']
#                                 256)
#
#  conv4_block3_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block3_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block3_1_relu (Activatio  (None, None, None,   0          ['conv4_block3_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block3_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block3_1_relu[0][0]']
#                                 256)
#
#  conv4_block3_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block3_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block3_2_relu (Activatio  (None, None, None,   0          ['conv4_block3_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block3_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block3_2_relu[0][0]']
#                                 1024)
#
#  conv4_block3_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block3_add (Add)         (None, None, None,   0           ['conv4_block2_out[0][0]',
#                                 1024)                             'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, None, None,   0           ['conv4_block3_add[0][0]']
#                                 1024)
#
#  conv4_block4_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block3_out[0][0]']
#                                 256)
#
#  conv4_block4_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block4_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block4_1_relu (Activatio  (None, None, None,   0          ['conv4_block4_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block4_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block4_1_relu[0][0]']
#                                 256)
#
#  conv4_block4_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block4_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block4_2_relu (Activatio  (None, None, None,   0          ['conv4_block4_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block4_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block4_2_relu[0][0]']
#                                 1024)
#
#  conv4_block4_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block4_add (Add)         (None, None, None,   0           ['conv4_block3_out[0][0]',
#                                 1024)                             'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, None, None,   0           ['conv4_block4_add[0][0]']
#                                 1024)
#
#  conv4_block5_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block4_out[0][0]']
#                                 256)
#
#  conv4_block5_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block5_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block5_1_relu (Activatio  (None, None, None,   0          ['conv4_block5_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block5_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block5_1_relu[0][0]']
#                                 256)
#
#  conv4_block5_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block5_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block5_2_relu (Activatio  (None, None, None,   0          ['conv4_block5_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block5_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block5_2_relu[0][0]']
#                                 1024)
#
#  conv4_block5_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block5_add (Add)         (None, None, None,   0           ['conv4_block4_out[0][0]',
#                                 1024)                             'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, None, None,   0           ['conv4_block5_add[0][0]']
#                                 1024)
#
#  conv4_block6_1_conv (Conv2D)   (None, None, None,   262400      ['conv4_block5_out[0][0]']
#                                 256)
#
#  conv4_block6_1_bn (BatchNormal  (None, None, None,   1024       ['conv4_block6_1_conv[0][0]']
#  ization)                       256)
#
#  conv4_block6_1_relu (Activatio  (None, None, None,   0          ['conv4_block6_1_bn[0][0]']
#  n)                             256)
#
#  conv4_block6_2_conv (Conv2D)   (None, None, None,   590080      ['conv4_block6_1_relu[0][0]']
#                                 256)
#
#  conv4_block6_2_bn (BatchNormal  (None, None, None,   1024       ['conv4_block6_2_conv[0][0]']
#  ization)                       256)
#
#  conv4_block6_2_relu (Activatio  (None, None, None,   0          ['conv4_block6_2_bn[0][0]']
#  n)                             256)
#
#  conv4_block6_3_conv (Conv2D)   (None, None, None,   263168      ['conv4_block6_2_relu[0][0]']
#                                 1024)
#
#  conv4_block6_3_bn (BatchNormal  (None, None, None,   4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       1024)
#
#  conv4_block6_add (Add)         (None, None, None,   0           ['conv4_block5_out[0][0]',
#                                 1024)                             'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, None, None,   0           ['conv4_block6_add[0][0]']
#                                 1024)
#
#  conv5_block1_1_conv (Conv2D)   (None, None, None,   524800      ['conv4_block6_out[0][0]']
#                                 512)
#
#  conv5_block1_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block1_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block1_1_relu (Activatio  (None, None, None,   0          ['conv5_block1_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block1_2_conv (Conv2D)   (None, None, None,   2359808     ['conv5_block1_1_relu[0][0]']
#                                 512)
#
#  conv5_block1_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block1_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block1_2_relu (Activatio  (None, None, None,   0          ['conv5_block1_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block1_0_conv (Conv2D)   (None, None, None,   2099200     ['conv4_block6_out[0][0]']
#                                 2048)
#
#  conv5_block1_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block1_2_relu[0][0]']
#                                 2048)
#
#  conv5_block1_0_bn (BatchNormal  (None, None, None,   8192       ['conv5_block1_0_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block1_3_bn (BatchNormal  (None, None, None,   8192       ['conv5_block1_3_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block1_add (Add)         (None, None, None,   0           ['conv5_block1_0_bn[0][0]',
#                                 2048)                             'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, None, None,   0           ['conv5_block1_add[0][0]']
#                                 2048)
#
#  conv5_block2_1_conv (Conv2D)   (None, None, None,   1049088     ['conv5_block1_out[0][0]']
#                                 512)
#
#  conv5_block2_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block2_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block2_1_relu (Activatio  (None, None, None,   0          ['conv5_block2_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block2_2_conv (Conv2D)   (None, None, None,   2359808     ['conv5_block2_1_relu[0][0]']
#                                 512)
#
#  conv5_block2_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block2_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block2_2_relu (Activatio  (None, None, None,   0          ['conv5_block2_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block2_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block2_2_relu[0][0]']
#                                 2048)
#
#  conv5_block2_3_bn (BatchNormal  (None, None, None,   8192       ['conv5_block2_3_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block2_add (Add)         (None, None, None,   0           ['conv5_block1_out[0][0]',
#                                 2048)                             'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, None, None,   0           ['conv5_block2_add[0][0]']
#                                 2048)
#
#  conv5_block3_1_conv (Conv2D)   (None, None, None,   1049088     ['conv5_block2_out[0][0]']
#                                 512)
#
#  conv5_block3_1_bn (BatchNormal  (None, None, None,   2048       ['conv5_block3_1_conv[0][0]']
#  ization)                       512)
#
#  conv5_block3_1_relu (Activatio  (None, None, None,   0          ['conv5_block3_1_bn[0][0]']
#  n)                             512)
#
#  conv5_block3_2_conv (Conv2D)   (None, None, None,   2359808     ['conv5_block3_1_relu[0][0]']
#                                 512)
#
#  conv5_block3_2_bn (BatchNormal  (None, None, None,   2048       ['conv5_block3_2_conv[0][0]']
#  ization)                       512)
#
#  conv5_block3_2_relu (Activatio  (None, None, None,   0          ['conv5_block3_2_bn[0][0]']
#  n)                             512)
#
#  conv5_block3_3_conv (Conv2D)   (None, None, None,   1050624     ['conv5_block3_2_relu[0][0]']
#                                 2048)
#
#  conv5_block3_3_bn (BatchNormal  (None, None, None,   8192       ['conv5_block3_3_conv[0][0]']
#  ization)                       2048)
#
#  conv5_block3_add (Add)         (None, None, None,   0           ['conv5_block2_out[0][0]',
#                                 2048)                             'conv5_block3_3_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
print (len(data_images))
# Out:
# 1000

# %% [markdown]
# Split train and val

# %%
image_list = os.listdir(image_path)
total = 1000
split = 857
image_list = image_list[:total]
len(image_list)
train_data_images = image_list[:split]
test_data_images = image_list[split:]

# %% [markdown]
# Tokenization

# %%
# loading captions from captions file
import pandas as pd

# loading captions.txt
#captions = pd.read_csv('/kaggle/input/flickr8k/captions.txt', sep=",")
captions = pd.read_csv('captions.txt', sep=",")
captions = captions.rename(columns=lambda x: x.strip().lower())
captions['image'] = captions['image'].apply(lambda x: x.split(".")[0])
captions = captions[['image', 'caption']]
# adding <start> and <end> to every caption
captions['caption'] = "<start> " + captions['caption'] + " <end>"

# in case we have any missing caption/blank caption drop it
print(captions.shape)
captions = captions.dropna()
print(captions.shape)

# training and testing image captions split
train_image_captions = {}
test_image_captions = {}

# list for storing every caption
all_captions = []

# storing training data
i = 0
for image in train_data_images:
    tempDf = captions['caption'][i]
    list_of_captions = tempDf.split()
    train_image_captions[image] = list_of_captions
    all_captions.append(list_of_captions)
    i += 1

# store testing data\
for image in test_data_images:
    tempDf = captions['caption'][i]
    list_of_captions = tempDf.split()
    print(list_of_captions)
    test_image_captions[image] = list_of_captions
    all_captions.append(list_of_captions)
    i+=1

print("Data Statistics")
print(f"Training Images Captions {len(train_image_captions.keys())}")
print(f"Testing Images Captions {len(test_image_captions.keys())}")
# Out:
# (40455, 2)
# (40455, 2)
# ['<start>', 'A', 'man', 'and', 'woman', 'standing', 'in', 'front', 'of', 'a', 'refreshment', 'stand', '<end>']
# ['<start>', 'A', 'man', 'in', 'a', 'black', 'shirt', 'and', 'jeans', 'walks', 'beside', 'a', 'woman', 'in', 'black', 'pants', 'and', 'a', 'flowery', 'shirt', 'in', 'front', 'of', 'a', 'refreshment', 'stand', 'with', 'others', 'walking', 'nearby', '.', '<end>']
# ['<start>', 'A', 'woman', 'with', 'a', 'floral', 'shirt', 'and', 'purse', 'and', 'a', 'man', 'with', 'a', 'black', 'shirt', 'are', 'walking', 'while', 'another', 'man', 'walks', 'behind', 'them', '.', '<end>']
# ['<start>', 'A', 'boy', 'lays', 'on', 'a', 'picnic', 'table', 'bench', '.', '<end>']
# ['<start>', 'A', 'child', 'is', 'laying', 'down', 'on', 'a', 'wooden', 'bench', '.', '<end>']
# ['<start>', 'A', 'child', 'is', 'on', 'a', 'bench', 'with', 'arms', 'stretched', 'out', '.', '<end>']
# ['<start>', 'A', 'little', 'boy', 'in', 'a', 'red', 'shirt', 'sitting', 'on', 'a', 'wooden', 'picnic', 'table', 'bench', '.', '<end>']
# ['<start>', 'A', 'little', 'boy', 'lies', 'down', 'on', 'a', 'picnic', 'table', 'bench', '.', '<end>']
# ['<start>', 'Dogs', 'fight', 'in', 'grass', 'over', 'toy', '.', '<end>']
# ['<start>', 'On', 'grass', ',', 'two', 'brown', 'dogs', 'tussle', 'for', 'orange', 'toy', '.', '<end>']
# ['<start>', 'Two', 'dogs', 'are', 'playing', 'rough', 'in', 'a', 'green', 'field', 'of', 'grass', '.', '<end>']
# ['<start>', 'Two', 'dogs', 'play', 'with', 'an', 'orange', 'toy', 'in', 'tall', 'grass', '.', '<end>']
# ['<start>', 'Two', 'large', 'brown', 'dogs', 'are', 'playing', 'in', 'the', 'grass', '.', '<end>']
# ['<start>', 'A', 'boy', 'and', 'a', 'person', 'suspended', 'above', 'a', 'dome', 'structure', '.', '<end>']
# ['<start>', 'A', 'boy', 'in', 'a', 'blue', 'shirt', 'is', 'posing', 'in', 'front', 'of', 'an', 'igloo', 'type', 'building', 'with', 'a', 'person', 'dangling', 'from', 'a', 'rope', 'above', 'the', 'building', '.', '<end>']
# ['<start>', 'A', 'boy', 'poses', 'for', 'a', 'picture', 'and', 'in', 'the', 'background', 'a', 'man', 'is', 'hanging', 'by', 'a', 'rope', '.', '<end>']
# ['<start>', 'A', 'boy', 'stands', 'near', 'a', 'structure', 'outside', '.', '<end>']
# ['<start>', 'a', 'young', 'man', 'wearing', 'a', 'blue', 'shirt', 'with', 'a', 'strange', 'white', 'building', 'in', 'the', 'background', '<end>']
# ['<start>', 'A', 'girl', 'in', 'a', 'brown', 'dress', 'surrounded', 'by', 'children', 'closes', 'her', 'eyes', '.', '<end>']
# ['<start>', 'A', 'girl', 'in', 'a', 'yellow', 'dress', 'with', 'the', 'sun', 'shining', 'on', 'her', 'face', '<end>']
# ['<start>', 'a', 'girl', 'in', 'yellow', 'dress', 'is', 'standing', 'with', 'her', 'eyes', 'closed', 'in', 'a', 'busy', 'park', '.', '<end>']
# ['<start>', 'A', 'young', 'girl', 'in', 'a', 'white', 'dress', '<end>']
# ['<start>', 'Children', 'at', 'a', 'park', '.', '<end>']
# ['<start>', 'A', 'man', 'in', 'a', 'black', 'jacket', 'is', 'taking', 'a', 'photo', 'of', 'a', 'man', 'in', 'a', 'red', 'jacket', '.', '<end>']
# ['<start>', 'A', 'man', 'in', 'a', 'black', 'outfit', 'is', 'taking', 'a', 'photograph', 'of', 'a', 'man', 'in', 'a', 'red', 'jacket', '.', '<end>']
# ['<start>', 'A', 'man', 'takes', 'a', 'picture', 'of', 'another', 'man', 'in', 'an', 'open', 'area', 'just', 'off', 'of', 'a', 'busy', 'street', '.', '<end>']
# ['<start>', 'A', 'young', 'man', 'taking', 'a', 'picture', 'of', 'another', 'young', 'man', 'outdoors', '<end>']
# ['<start>', 'Young', 'man', 'takes', 'picture', 'of', 'another', 'young', 'man', 'in', 'front', 'of', 'church', '.', '<end>']
# ['<start>', 'A', 'family', 'sits', 'on', 'a', 'bench', 'near', 'a', 'beach', '.', '<end>']
# ['<start>', 'A', 'family', 'sits', 'on', 'a', 'bench', 'overlooking', 'the', 'beach', '.', '<end>']
# ['<start>', 'A', 'man', ',', 'woman', ',', 'girl', ',', 'and', 'boy', 'sit', 'on', 'a', 'concrete', 'bench', 'by', 'a', 'beach', '.', '<end>']
# ['<start>', 'Family', 'sitting', 'on', 'a', 'bench', 'near', 'the', 'beach', '.', '<end>']
# ['<start>', 'Taking', 'a', 'break', 'while', 'vacationing', 'at', 'the', 'beach', '<end>']
# ['<start>', 'A', 'group', 'of', 'climbers', 'begin', 'up', 'a', 'sheer', 'rock', 'face', '.', '<end>']
# ['<start>', 'A', 'group', 'of', 'rock', 'climbers', 'climb', 'a', 'rock', 'wall', 'in', 'a', 'forest', '.', '<end>']
# ['<start>', 'Many', 'people', 'are', 'climbing', 'the', 'mountain', 'surrounded', 'by', 'pretty', 'green', 'trees', '.', '<end>']
# ['<start>', 'People', 'at', 'a', 'distance', 'trying', 'to', 'climb', 'a', 'cliff', '.', '<end>']
# ['<start>', 'The', 'flat', 'side', 'of', 'a', 'large', ',', 'rocky', 'mountain', '.', '<end>']
# ['<start>', 'two', 'men', 'cleaning', 'the', 'outside', 'windows', 'of', 'a', 'yacht', '<end>']
# ['<start>', 'Two', 'men', 'climb', 'the', 'side', 'of', 'a', 'boat', '.', '<end>']
# ['<start>', 'Two', 'men', 'on', 'the', 'side', 'of', 'a', 'barge', '<end>']
# ['<start>', 'Two', 'people', 'outside', 'cleaning', 'windows', 'while', 'on', 'a', 'ledge', 'of', 'a', 'boat', '.', '<end>']
# ['<start>', 'Two', 'people', 'stand', 'on', 'the', 'side', 'of', 'a', 'large', 'white', 'and', 'red', 'boat', '.', '<end>']
# ['<start>', 'Two', 'children', 'are', 'laughing', 'in', 'the', 'grass', '.', '<end>']
# ['<start>', 'Two', 'girls', 'laughing', 'outside', 'in', 'a', 'yard', '.', '<end>']
# ['<start>', 'Two', 'girls', 'standing', 'on', 'grass', 'face', 'each', 'other', '.', '<end>']
# ['<start>', 'Two', 'young', 'girls', 'are', 'playing', 'and', 'laughing', 'in', 'a', 'green', 'grassy', 'yard', '.', '<end>']
# ['<start>', 'Two', 'young', 'girls', 'playing', 'together', '.', '<end>']
# ['<start>', 'A', 'boy', 'in', 'a', 'red', 'and', 'white', 'shirt', 'is', 'on', 'a', 'swing', '.', '<end>']
# ['<start>', 'A', 'child', 'looking', 'back', 'on', 'a', 'fast', 'moving', 'swing', '.', '<end>']
# ['<start>', 'A', 'litlle', 'boy', 'playing', 'on', 'a', 'swing', '<end>']
# ['<start>', 'A', 'young', 'boy', 'in', 'orange', 'and', 'white', 'swings', 'in', 'a', 'playground', 'at', 'a', 'park', '.', '<end>']
# ['<start>', 'A', 'young', 'boy', 'plays', 'on', 'a', 'swing', '.', '<end>']
# ['<start>', 'A', 'boy', 'eats', 'with', 'a', 'spoon', '.', '<end>']
# ['<start>', 'A', 'little', 'boy', 'holds', 'a', 'spoon', 'up', 'to', 'his', 'mouth', '.', '<end>']
# ['<start>', 'A', 'little', 'boy', 'is', 'eating', 'his', 'food', 'off', 'of', 'a', 'spoon', 'while', 'sitting', 'on', 'a', 'patio', '.', '<end>']
# ['<start>', 'A', 'small', 'child', 'dressed', 'in', 'green', 'is', 'eating', 'with', 'a', 'spoon', '.', '<end>']
# ['<start>', 'A', 'young', 'child', 'holds', 'a', 'spoon', 'to', 'its', 'mouth', 'while', 'sitting', 'in', 'a', 'chair', '.', '<end>']
# ['<start>', 'A', 'girl', 'walking', 'alone', 'at', 'night', 'on', 'a', 'street', '.', '<end>']
# ['<start>', 'A', 'woman', 'in', 'a', 'blue', 'coat', 'and', 'blue', 'heels', 'walks', 'down', 'a', 'city', 'sidewalk', 'at', 'night', '.', '<end>']
# ['<start>', 'A', 'woman', 'walking', 'down', 'a', 'brick', 'sidewalk', '.', '<end>']
# ['<start>', 'A', 'woman', 'walks', 'down', 'a', 'brick', 'sidewalk', 'at', 'night', '.', '<end>']
# ['<start>', 'A', 'woman', 'walks', 'down', 'a', 'city', 'sidewalk', 'at', 'night', '.', '<end>']
# ['<start>', 'A', 'black', 'dog', 'and', 'a', 'brown', 'dog', 'playing', 'in', 'tall', 'weeds', '.', '<end>']
# ['<start>', 'A', 'brown', 'dog', 'and', 'a', 'black', 'dog', 'are', 'standing', 'against', 'each', 'other', 'in', 'some', 'grass', '<end>']
# ['<start>', 'Two', 'dogs', 'are', 'playing', 'outside', 'in', 'a', 'field', '.', '<end>']
# ['<start>', 'Two', 'dogs', 'play', 'in', 'tall', 'grass', '.', '<end>']
# ['<start>', 'Two', 'dogs', 'wrestle', 'together', 'in', 'the', 'long', 'grass', '.', '<end>']
# ['<start>', 'A', 'brown', 'dog', 'jumping', 'in', 'the', 'air', 'on', 'a', 'brown', 'plain', '.', '<end>']
# ['<start>', 'A', 'brown', 'dog', 'jumping', 'into', 'the', 'air', 'to', 'catch', 'a', 'ball', '.', '<end>']
# ['<start>', 'A', 'brown', 'dog', 'leaping', 'to', 'catch', 'a', 'ball', '.', '<end>']
# ['<start>', 'A', 'coppery', 'dog', 'leaps', 'to', 'catch', 'a', 'ball', '.', '<end>']
# ['<start>', 'A', 'dog', 'leaps', 'into', 'the', 'air', 'in', 'a', 'grassy', 'field', 'surrounded', 'by', 'trees', '.', '<end>']
# ['<start>', 'A', 'child', 'in', 'gray', 'clothes', 'is', 'sleeping', 'on', 'a', 'red', 'cushion', '.', '<end>']
# ['<start>', 'A', 'little', 'boy', 'has', 'fallen', 'asleep', 'on', 'a', 'miniature', 'sofa', 'and', 'a', 'pacifier', 'in', 'his', 'mouth', '.', '<end>']
# ['<start>', 'A', 'sleeping', 'child', 'sucking', 'on', 'a', 'pacifier', '.', '<end>']
# ['<start>', 'A', 'toddler', 'wearing', 'a', 'pacifier', 'is', 'sleeping', 'on', 'a', 'red', 'blanket', 'with', 'a', 'teddy', 'bear', 'at', 'his', 'side', '.', '<end>']
# ['<start>', 'a', 'young', 'baby', 'sucking', 'a', 'Binky', 'asleep', 'in', 'a', 'chair', '.', '<end>']
# ['<start>', 'A', 'baby', 'girl', 'playing', 'at', 'a', 'park', '.', '<end>']
# ['<start>', 'A', 'closeup', 'of', 'a', 'child', 'on', 'a', 'playground', 'with', 'adult', 'supervision', '.', '<end>']
# ['<start>', 'A', 'young', 'boy', 'poses', 'for', 'a', 'picture', 'in', 'front', 'of', 'a', 'playground', '.', '<end>']
# ['<start>', 'A', 'young', 'girl', 'is', 'smiling', 'in', 'front', 'of', 'the', 'camera', 'at', 'a', 'park', '.', '<end>']
# ['<start>', 'There', 'is', 'a', 'little', 'blond', 'hair', 'girl', 'with', 'a', 'green', 'sweatshirt', 'and', 'a', 'red', 'shirt', 'playing', 'on', 'a', 'playground', '.', '<end>']
# ['<start>', 'A', 'girl', 'in', 'a', 'helmet', 'rides', 'a', 'horse', '.', '<end>']
# ['<start>', 'A', 'girl', 'rides', 'a', 'horse', '.', '<end>']
# ['<start>', 'A', 'young', 'girl', 'wearing', 'a', 'helmet', 'and', 'riding', 'a', 'brown', 'horse', '.', '<end>']
# ['<start>', 'Girl', 'with', 'black', 'helmet', 'riding', 'brown', 'dappled', 'horse', '<end>']
# ['<start>', 'The', 'little', 'girl', 'is', 'riding', 'in', 'a', 'brown', 'horse', '.', '<end>']
# ['<start>', 'a', 'Korean', 'man', 'sells', 'soda', '.', '<end>']
# ['<start>', 'A', 'man', 'is', 'sitting', 'at', 'an', 'outside', 'bar', 'near', 'many', 'soda', 'and', 'beer', 'cans', '.', '<end>']
# ['<start>', 'A', 'man', 'wearing', 'glasses', 'with', 'aluminum', 'cans', 'lined', 'up', 'in', 'front', 'of', 'him', '.', '<end>']
# ['<start>', 'An', 'elderly', 'man', 'is', 'smiling', 'while', 'sitting', 'in', 'front', 'of', 'a', 'row', 'of', 'soda', 'cans', '.', '<end>']
# ['<start>', 'Vendor', 'selling', 'drinks', 'in', 'a', 'stall', '.', '<end>']
# ['<start>', 'The', 'hatted', 'males', 'pose', 'for', 'a', 'picture', '.', '<end>']
# ['<start>', 'The', 'two', 'men', 'are', 'wearing', 'tall', 'hats', ',', 'one', 'hat', 'is', 'a', 'red', 'print', 'and', 'the', 'other', 'is', 'gold', 'colored', '.', '<end>']
# ['<start>', 'Two', 'men', 'in', 'tall', 'hats', 'frown', 'at', 'the', 'camera', '<end>']
# ['<start>', 'Two', 'men', 'wear', 'silly', 'stove', 'pipe', 'hats', 'and', 'wear', 'makeup', '.', '<end>']
# ['<start>', 'Two', 'people', 'wearing', 'hats', 'sit', 'and', 'look', 'at', 'the', 'camera', '.', '<end>']
# ['<start>', 'A', 'person', 'in', 'a', 'blue', 'shirt', 'sits', 'behind', 'two', 'people', 'sitting', 'on', 'a', 'wood', 'bench', '.', '<end>']
# ['<start>', 'People', 'sit', 'on', 'benches', '.', '<end>']
# ['<start>', 'People', 'sitting', 'on', 'benches', 'in', 'a', 'public', 'area', '.', '<end>']
# ['<start>', 'Three', 'people', 'sit', 'on', 'wood', 'benches', 'set', 'on', 'white', 'and', 'orange', 'tile', '.', '<end>']
# ['<start>', 'Three', 'people', 'sit', 'waiting', 'in', 'a', 'lobby', '.', '<end>']
# ['<start>', 'A', 'man', 'in', 'sunglasses', 'on', 'an', 'overpass', '.', '<end>']
# ['<start>', 'A', 'man', 'looking', 'at', 'the', 'camera', 'with', 'another', 'man', 'wearing', 'a', 'mask', '.', '<end>']
# ['<start>', 'A', 'man', 'wearing', 'sunglasses', 'is', 'standing', 'next', 'to', 'a', 'person', 'who', 'is', 'wearing', 'a', 'hat', 'and', 'breathing', 'mask', '.', '<end>']
# ['<start>', 'The', 'man', 'is', 'wearing', 'a', 'white', 'shirt', 'and', 'sunglasses', '.', '<end>']
# ['<start>', 'There', 'are', 'two', 'men', 'with', 'sunglasses', ',', 'one', 'of', 'which', 'is', 'wearing', 'a', 'hat', 'and', 'a', 'backpack', '.', '<end>']
# ['<start>', 'A', 'boy', 'in', 'a', 'wetsuit', 'jumps', 'into', 'a', 'pool', 'with', 'a', 'bald', 'man', '.', '<end>']
# ['<start>', 'A', 'boy', 'with', 'goggles', 'jumping', 'into', 'a', 'pool', 'containing', 'a', 'man', '.', '<end>']
# ['<start>', 'A', 'child', 'is', 'jumping', 'into', 'a', 'pool', 'while', 'a', 'man', 'is', 'watching', 'the', 'child', '<end>']
# ['<start>', 'A', 'swimming', 'person', 'is', 'watching', 'a', 'child', 'jump', 'into', 'a', 'pool', 'with', 'blue', 'water', '.', '<end>']
# ['<start>', 'A', 'young', 'boy', 'jumps', 'in', 'a', 'swimming', 'pool', 'towards', 'a', 'bald', 'man', 'in', 'the', 'water', '.', '<end>']
# ['<start>', 'A', 'boy', 'flips', 'off', 'a', 'diving', 'board', 'into', 'a', 'pool', '.', '<end>']
# ['<start>', 'A', 'boy', 'is', 'diving', 'off', 'a', 'diving', 'board', 'into', 'a', 'swimming', 'pool', '.', '<end>']
# ['<start>', 'A', 'child', 'is', 'diving', 'into', 'a', 'pool', '.', '<end>']
# ['<start>', 'A', 'child', 'jumping', 'into', 'a', 'swimming', 'pool', 'from', 'the', 'diving', 'board', '.', '<end>']
# ['<start>', 'Child', 'flips', 'off', 'pool', 'diving', 'board', ',', 'man', 'and', 'another', 'tumbling', 'child', 'at', 'poolside', '.', '<end>']
# ['<start>', 'A', 'lady', 'holds', 'a', 'little', 'girl', 'who', 'is', 'trying', 'to', 'catch', 'bubbles', '.', '<end>']
# ['<start>', 'A', 'woman', 'is', 'holding', 'a', 'little', 'girl', 'who', 'is', 'trying', 'to', 'catch', 'bubbles', '.', '<end>']
# ['<start>', 'A', 'woman', 'with', 'holding', 'a', 'young', 'girl', 'playing', 'with', 'bubbles', 'at', 'a', 'picnic', '.', '<end>']
# ['<start>', 'A', 'young', 'woman', 'in', 'a', 'blue', 'shirt', 'stands', ',', 'holding', 'a', 'young', 'girl', 'in', 'a', 'denim', 'dress', '.', '<end>']
# ['<start>', 'There', 'is', 'a', 'woman', 'holding', 'her', 'baby', 'daughter', 'while', 'the', 'daughter', 'claps', '.', '<end>']
# ['<start>', 'A', 'brown', 'dog', 'biting', 'a', 'gray', 'dogs', 'ear', '.', '<end>']
# ['<start>', 'Brown', 'dog', 'biting', 'a', 'grey', 'dogs', 'ear', '.', '<end>']
# ['<start>', 'Tan', 'dog', 'on', 'grass', 'with', 'mouth', 'open', ',', 'about', 'to', 'bite', 'gray', 'dog', "'s", 'ear', '.', '<end>']
# ['<start>', 'Two', 'dogs', 'are', 'playing', 'in', 'a', 'grassy', 'field', ';', 'one', 'dog', 'is', 'biting', 'the', 'ear', 'of', 'the', 'other', 'dog', '.', '<end>']
# ['<start>', 'Two', 'dogs', 'are', 'playing', 'together', 'on', 'green', 'grass', '.', '<end>']
# ['<start>', 'Girls', 'wearing', 'sports', 'uniforms', 'and', 'eye', 'protection', '.', '<end>']
# ['<start>', 'Several', 'female', 'lacrosse', 'players', 'are', 'going', 'after', 'a', 'ball', '.', '<end>']
# ['<start>', 'These', 'girls', 'are', 'in', 'uniforms', 'and', 'are', 'playing', 'field', 'hockey', '.', '<end>']
# ['<start>', 'The', 'woman', 'lacrosse', 'player', 'in', 'blue', 'is', 'about', 'to', 'catch', 'the', 'ball', '.', '<end>']
# ['<start>', 'Women', 'play', 'lacrosse', '.', '<end>']
# ['<start>', 'A', 'dog', 'in', 'a', 'number', 'six', 'jersey', 'is', 'running', 'through', 'a', 'field', '.', '<end>']
# ['<start>', 'A', 'dog', 'is', 'leaping', 'through', 'the', 'grass', '.', '<end>']
# ['<start>', 'A', 'dog', 'is', 'wearing', 'a', 'red', 'number', '6', 'and', 'running', 'through', 'a', 'field', 'of', 'green', 'grass', 'while', 'being', 'chased', 'by', 'a', 'bird', '.', '<end>']
# ['<start>', 'A', 'white', 'and', 'tan', 'dog', 'leaps', 'through', 'the', 'air', '.', '<end>']
# ['<start>', 'The', 'dog', 'in', 'a', 'vest', 'leaps', 'in', 'the', 'air', 'and', 'there', 'is', 'a', 'bird', 'flying', '.', '<end>']
# ['<start>', 'A', 'brown', 'horse', 'and', 'a', 'black', 'foal', 'on', 'the', 'beach', '<end>']
# ['<start>', 'A', 'brown', 'horse', 'stands', 'near', 'a', 'black', 'horse', 'that', 'is', 'sitting', 'on', 'the', 'ground', '.', '<end>']
# ['<start>', 'A', 'large', 'brown', 'horse', 'stands', 'over', 'a', 'small', 'black', 'colt', 'that', 'is', 'kneeling', 'on', 'the', 'sand', '.', '<end>']
# ['<start>', 'An', 'adult', 'horse', 'approaching', 'a', 'foal', 'on', 'a', 'sandy', 'plain', '.', '<end>']
# ['<start>', 'A', 'thin', 'brown', 'horse', 'standing', 'and', 'a', 'small', 'black', 'horse', 'sitting', 'on', 'sand', '.', '<end>']
# Data Statistics
# Training Images Captions 857
# Testing Images Captions 143

# %% [markdown]
# Tokenizer

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# tokenize evry captions, remove punctuations, lowercase everything
for key, value in train_image_captions.items():
    ls = []
    for v in value:
        doc = nlp(v)
        new_v = " "
        for token in doc:
            if not token.is_punct:
                if token.text not in [" ", "\n", "\n\n"]:
                    new_v = new_v + " " + token.text.lower()
        
        new_v = new_v.strip()
        ls.append(new_v)
    train_image_captions[key] = ls
#print(train_image_captions)

# create a vocabulary of all the unique words present in captions
# flatten the list
all_captions = [caption for list_of_captions in all_captions for caption in list_of_captions]

# use spacy to convert to lowercase and reject any special characters 
tokens = []
for captions in all_captions:
    doc = nlp(captions)
    for token in doc:
        if not token.is_punct:
            if token.text not in [" ", "\n", "\n\n"]:
                tokens.append(token.text.lower())

# get tokens with frequency less than 10
import collections
word_count_dict = collections.Counter(tokens)
reject_words = []
for key, value in word_count_dict.items():
    if value < 10:
        reject_words.append(key)
        
reject_words.append("<")
reject_words.append(">")

 # remove tokens that are in reject words
tokens = [x for x in tokens if x not in reject_words]
#print(tokens)
# convert the token to equivalent index using Tokenizer class of Keras
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='0')
tokenizer.fit_on_texts(tokens)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/52/80l4_7s57lb7fc5_j7qxm4zw0000gn/T/ipykernel_43850/1807036706.py in <module>
#      25 tokens = []
#      26 for captions in all_captions:
# ---> 27     doc = nlp(captions)
#      28     for token in doc:
#      29         if not token.is_punct:
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1011                 error_handler = proc.get_error_handler()
#    1012             try:
# -> 1013                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1014             except KeyError as e:
#    1015                 # This typically happens if a component is not initialized
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.predict()
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in predict(self, X)
#     313         only the output, instead of the `(output, callback)` tuple.
#     314         """
# --> 315         return self._func(self, X, is_train=False)[0]
#     316
#     317     def finish_update(self, optimizer: Optimizer) -> None:
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/spacy/ml/tb_framework.py in forward(model, X, is_train)
#      31
#      32 def forward(model, X, is_train):
# ---> 33     step_model = ParserStepModel(
#      34         X,
#      35         model.layers,
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/spacy/ml/parser_model.pyx in spacy.ml.parser_model.ParserStepModel.__init__()
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/with_array.py in forward(model, Xseq, is_train)
#      38         return model.layers[0](Xseq, is_train)
#      39     else:
# ---> 40         return _list_forward(cast(Model[List2d, List2d], model), Xseq, is_train)
#      41
#      42
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/with_array.py in _list_forward(model, Xs, is_train)
#      74     lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      75     Xf = layer.ops.flatten(Xs, pad=pad)  # type: ignore
# ---> 76     Yf, get_dXf = layer(Xf, is_train)
#      77
#      78     def backprop(dYs: List2d) -> List2d:
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/residual.py in forward(model, X, is_train)
#      38             return d_output + dX
#      39
# ---> 40     Y, backprop_layer = model.layers[0](X, is_train)
#      41     if isinstance(X, list):
#      42         return [X[i] + Y[i] for i in range(len(X))], backprop
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/layernorm.py in forward(model, X, is_train)
#      23
#      24 def forward(model: Model[InT, InT], X: InT, is_train: bool) -> Tuple[InT, Callable]:
# ---> 25     N, mu, var = _get_moments(model.ops, X)
#      26     Xhat = (X - mu) * var ** (-1.0 / 2.0)
#      27     Y, backprop_rescale = _begin_update_scale_shift(model, Xhat)
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/thinc/layers/layernorm.py in _get_moments(ops, X)
#      75     # TODO: Do mean methods
#      76     mu: Floats2d = X.mean(axis=1, keepdims=True)
# ---> 77     var: Floats2d = X.var(axis=1, keepdims=True) + 1e-08
#      78     return cast(Floats2d, ops.asarray_f([X.shape[1]])), mu, var
#      79
#
# ~/opt/anaconda3/envs/ml/lib/python3.8/site-packages/numpy/core/_methods.py in _var(a, axis, dtype, out, ddof, keepdims, where)
#     244
#     245     # Compute degrees of freedom and make sure it is not negative.
# --> 246     rcount = um.maximum(rcount - ddof, 0)
#     247
#     248     # divide by degrees of freedom
#
# KeyboardInterrupt:

# %%
tokenizer.word_index
# Out:
# {'0': 1,
#  'a': 2,
#  't': 3,
#  'e': 4,
#  'n': 5,
#  'r': 6,
#  'i': 7,
#  's': 8,
#  'o': 9,
#  'd': 10,
#  'l': 11,
#  'h': 12,
#  'g': 13,
#  'w': 14,
#  'c': 15,
#  'b': 16,
#  'u': 17,
#  'p': 18,
#  'm': 19,
#  'y': 20,
#  'f': 21,
#  'k': 22,
#  'v': 23,
#  'j': 24,
#  'x': 25,
#  'z': 26}

# %%
# compute length of vocabulary and maximum length of a caption (for padding)
vocab_len = len(tokenizer.word_counts) + 1
print(f"Vocabulary length - {vocab_len}")

max_caption_len = max([len(x) for x in all_captions])
#max_caption_len = 10

print(f"Maximum length of caption - {max_caption_len}")
# Out:
# Vocabulary length - 156
# Maximum length of caption - 13

# %% [markdown]
# BEGINNNING OF LSTM FIX FIRST BLOCK

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# generator function to generate inputs for model
def create_training_data(captions, images, tokenizer, max_caption_length, vocab_len, photos_per_batch):
    
    X1, X2, y = list(), list(), list()
    n=0
    for i in range(len(captions)):
        #img_name = captions[i][0]
        img = images[i]
        cap = captions[img]

        tokenized_captions = tokenizer.texts_to_sequences(cap)
        print(cap)
        print(tokenized_captions)
        input_seq = pad_sequences([inp], maxlen=max_caption_length)[0]
        X1
        
    '''
    # loop through every image
    while 1:
        for key, cap in list(captions.items()):
            n+=1
            # retrieve the photo feature
            image = key
            
            for c in cap:
                # encode the sequence #TODO
                sequence = [tokenizer.word_index[word] for word in c.split(' ') if word in list(tokenizer.word_index.keys())]
                
                # split one sequence into multiple X, y pairs
                
                for i in range(1, len(sequence)):
                    # creating input, output
                    inp, out = sequence[:i], sequence[i]
                    # padding input                     
                    input_seq = pad_sequences([inp], maxlen=max_caption_length)[0]
                    # encode output sequence
                    output_seq = to_categorical([out], num_classes=vocab_len)[0]
                    # store
                    X1.append(image)
                    X2.append(input_seq)
                    y.append(output_seq)
                    
            # yield the batch data
            if n==photos_per_batch:
                yield ([np.array(X1), np.array(X2)], np.array(y))
                X1, X2, y = list(), list(), list()
                n=0
    '''

# %%
import keras

def create_model(max_caption_length, vocab_length):
    
    # sub network for handling the image feature part
    input_layer1 = keras.Input(shape=(18432,)) #18432
    feature1 = keras.layers.Dropout(0.2)(input_layer1)
    feature2 = keras.layers.Dense(max_caption_length*4, activation='relu')(feature1)
    feature3 = keras.layers.Dense(max_caption_length*4, activation='relu')(feature2)
    feature4 = keras.layers.Dense(max_caption_length*4, activation='relu')(feature3)
    feature5 = keras.layers.Dense(max_caption_length*4, activation='relu')(feature4)
    
    # sub network for handling the text generation part
    input_layer2 = keras.Input(shape=(max_caption_len,)) #max_caption_length
    cap_layer1 = keras.layers.Embedding(vocab_length, 300, input_length=max_caption_length)(input_layer2)
    cap_layer2 = keras.layers.Dropout(0.2)(cap_layer1)
    cap_layer3 = keras.layers.LSTM(max_caption_length*4, activation='relu', return_sequences=True)(cap_layer2)
    cap_layer4 = keras.layers.LSTM(max_caption_length*4, activation='relu', return_sequences=True)(cap_layer3)
    cap_layer5 = keras.layers.LSTM(max_caption_length*4, activation='relu', return_sequences=True)(cap_layer4)
    cap_layer6 = keras.layers.LSTM(max_caption_length*4, activation='relu')(cap_layer5)
    
    # merging the two sub network
    decoder1 = keras.layers.merge.add([feature5, cap_layer6])
    decoder2 = keras.layers.Dense(256, activation='relu')(decoder1)
    decoder3 = keras.layers.Dense(256, activation='relu')(decoder2)
    
    # output is the next word in sequence
    output_layer = keras.layers.Dense(vocab_length, activation='softmax')(decoder3)
    model = keras.models.Model(inputs=[input_layer1, input_layer2], outputs=output_layer)
    
    model.summary()

    return model

# %%
print(list(train_image_captions.items())[0])
# Out:
# ('2387197355_237f6f41ee.jpg', ['< start >', 'a', 'child', 'in', 'a', 'pink', 'dress', 'is', 'climbing', 'up', 'a', 'set', 'of', 'stairs', 'in', 'an', 'entry', 'way', '', '< end >'])

# %%
import spacy
nlp = spacy.load('en_core_web_lg')

# create word embeddings
embedding_dimension = 300
embedding_matrix = np.zeros((vocab_len, embedding_dimension))

# travel through every word in vocabulary and get its corresponding vector
for word, index in tokenizer.word_index.items():
    doc = nlp(word)
    embedding_vector = np.array(doc.vector)
    embedding_matrix[index] = embedding_vector

predictive_model = create_model(max_caption_len, vocab_len)
# adding embeddings to model
predictive_model.layers[2]
predictive_model.layers[2].set_weights([embedding_matrix])
predictive_model.layers[2].trainable = False
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 13)]         0           []
#
#  input_2 (InputLayer)           [(None, 18432)]      0           []
#
#  embedding (Embedding)          (None, 13, 300)      46800       ['input_3[0][0]']
#
#  dropout (Dropout)              (None, 18432)        0           ['input_2[0][0]']
#
#  dropout_1 (Dropout)            (None, 13, 300)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 52)           958516      ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 13, 52)       73424       ['dropout_1[0][0]']
#
#  dense_1 (Dense)                (None, 52)           2756        ['dense[0][0]']
#
#  lstm_1 (LSTM)                  (None, 13, 52)       21840       ['lstm[0][0]']
#
#  dense_2 (Dense)                (None, 52)           2756        ['dense_1[0][0]']
#
#  lstm_2 (LSTM)                  (None, 13, 52)       21840       ['lstm_1[0][0]']
#
#  dense_3 (Dense)                (None, 52)           2756        ['dense_2[0][0]']
#
#  lstm_3 (LSTM)                  (None, 52)           21840       ['lstm_2[0][0]']
#
#  add (Add)                      (None, 52)           0           ['dense_3[0][0]',
#                                                                   'lstm_3[0][0]']
#
#  dense_4 (Dense)                (None, 256)          13568       ['add[0][0]']
#
#  dense_5 (Dense)                (None, 256)          65792       ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 156)          40092       ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 1,271,980
# Trainable params: 1,271,980
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# get training data
train_data = create_training_data(train_image_captions, train_data_images, tokenizer, max_caption_len, vocab_len, 32)
# initialize model
model = create_model(max_caption_len, vocab_len)
steps_per_epochs = len(train_image_captions)//32

# compile model
model.compile(optimizer='adam', loss='categorical_crossentropy')
model.fit_generator(train_data, epochs=100, steps_per_epoch=steps_per_epochs)
# Out:
# ['< start >', 'a', 'child', 'in', 'a', 'pink', 'dress', 'is', 'climbing', 'up', 'a', 'set', 'of', 'stairs', 'in', 'an', 'entry', 'way', '', '< end >']
# [[3], [1], [30], [4], [1], [141], [142], [7], [61], [51], [1], [], [12], [], [4], [26], [], [], [], [2]]
# ['< start >', 'a', 'girl', 'going', 'into', 'a', 'wooden', 'building', '', '< end >']
# [[3], [1], [16], [], [42], [1], [], [116], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'climbing', 'into', 'a', 'wooden', 'playhouse', '', '< end >']
# [[3], [1], [32], [16], [61], [42], [1], [], [], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'climbing', 'the', 'stairs', 'to', 'her', 'playhouse', '', '< end >']
# [[3], [1], [32], [16], [61], [5], [], [23], [69], [], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'in', 'a', 'pink', 'dress', 'going', 'into', 'a', 'wooden', 'cabin', '', '< end >']
# [[3], [1], [32], [16], [4], [1], [141], [142], [], [42], [1], [], [], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'and', 'a', 'spotted', 'dog', 'are', 'fighting', '< end >']
# [[3], [1], [17], [9], [8], [1], [], [9], [22], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'and', 'a', 'tri colored', 'dog', 'playing', 'with', 'each', 'other', 'on', 'the', 'road', '', '< end >']
# [[3], [1], [17], [9], [8], [1], [], [9], [29], [10], [117], [79], [6], [5], [122], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'and', 'a', 'white', 'dog', 'with', 'brown', 'spots', 'are', 'staring', 'at', 'each', 'other', 'in', 'the', 'street', '', '< end >']
# [[3], [1], [17], [9], [8], [1], [19], [9], [10], [18], [], [22], [], [15], [117], [79], [4], [5], [60], [], [2]]
# ['< start >', 'two', 'dogs', 'of', 'different', 'breeds', 'looking', 'at', 'each', 'other', 'on', 'the', 'road', '', '< end >']
# [[3], [13], [33], [12], [], [], [108], [15], [117], [79], [6], [5], [122], [], [2]]
# ['< start >', 'two', 'dogs', 'on', 'pavement', 'moving', 'toward', 'each', 'other', '', '< end >']
# [[3], [13], [33], [6], [], [], [], [117], [79], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'covered', 'in', 'paint', 'sits', 'in', 'front', 'of', 'a', 'painted', 'rainbow', 'with', 'her', 'hands', 'in', 'a', 'bowl', '', '< end >']
# [[3], [1], [32], [16], [96], [4], [], [65], [4], [38], [12], [1], [], [], [10], [69], [], [4], [1], [], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'is', 'sitting', 'in', 'front', 'of', 'a', 'large', 'painted', 'rainbow', '', '< end >']
# [[3], [1], [32], [16], [7], [39], [4], [38], [12], [1], [62], [], [], [], [2]]
# ['< start >', 'a', 'small', 'girl', 'in', 'the', 'grass', 'plays', 'with', 'fingerpaints', 'in', 'front', 'of', 'a', 'white', 'canvas', 'with', 'a', 'rainbow', 'on', 'it', '', '< end >']
# [[3], [1], [46], [16], [4], [5], [49], [89], [10], [], [4], [38], [12], [1], [19], [], [10], [1], [], [6], [103], [], [2]]
# ['< start >', 'there', 'is', 'a', 'girl', 'with', 'pigtails', 'sitting', 'in', 'front', 'of', 'a', 'rainbow', 'painting', '', '< end >']
# [[3], [134], [7], [1], [16], [10], [], [39], [4], [38], [12], [1], [], [], [], [2]]
# ['< start >', 'young', 'girl', 'with', 'pigtails', 'painting', 'outside', 'in', 'the', 'grass', '', '< end >']
# [[3], [21], [16], [10], [], [], [71], [4], [5], [49], [], [2]]
# ['< start >', 'a', 'man', 'lays', 'on', 'a', 'bench', 'while', 'his', 'dog', 'sits', 'by', 'him', '', '< end >']
# [[3], [1], [11], [], [6], [1], [90], [34], [35], [9], [65], [55], [118], [], [2]]
# ['< start >', 'a', 'man', 'lays', 'on', 'the', 'bench', 'to', 'which', 'a', 'white', 'dog', 'is', 'also', 'tied', '', '< end >']
# [[3], [1], [11], [], [6], [5], [90], [23], [], [1], [19], [9], [7], [], [], [], [2]]
# ['< start >', 'a', 'man', 'sleeping', 'on', 'a', 'bench', 'outside', 'with', 'a', 'white', 'and', 'black', 'dog', 'sitting', 'next', 'to', 'him', '', '< end >']
# [[3], [1], [11], [], [6], [1], [90], [71], [10], [1], [19], [8], [17], [9], [39], [68], [23], [118], [], [2]]
# ['< start >', 'a', 'shirtless', 'man', 'lies', 'on', 'a', 'park', 'bench', 'with', 'his', 'dog', '', '< end >']
# [[3], [1], [], [11], [], [6], [1], [123], [90], [10], [35], [9], [], [2]]
# ['< start >', 'man', 'laying', 'on', 'bench', 'holding', 'leash', 'of', 'dog', 'sitting', 'on', 'ground', '< end >']
# [[3], [11], [], [6], [90], [66], [], [12], [9], [39], [6], [], [2]]
# ['< start >', 'a', 'man', 'in', 'an', 'orange', 'hat', 'starring', 'at', 'something', '', '< end >']
# [[3], [1], [11], [4], [26], [119], [91], [], [15], [], [], [2]]
# ['< start >', 'a', 'man', 'wears', 'an', 'orange', 'hat', 'and', 'glasses', '', '< end >']
# [[3], [1], [11], [], [26], [119], [91], [8], [], [], [2]]
# ['< start >', 'a', 'man', 'with', 'gauges', 'and', 'glasses', 'is', 'wearing', 'a', 'blitz', 'hat', '', '< end >']
# [[3], [1], [11], [10], [], [8], [], [7], [31], [1], [], [91], [], [2]]
# ['< start >', 'a', 'man', 'with', 'glasses', 'is', 'wearing', 'a', 'beer', 'can', 'crocheted', 'hat', '', '< end >']
# [[3], [1], [11], [10], [], [7], [31], [1], [], [], [], [91], [], [2]]
# ['< start >', 'the', 'man', 'with', 'pierced', 'ears', 'is', 'wearing', 'glasses', 'and', 'an', 'orange', 'hat', '', '< end >']
# [[3], [5], [11], [10], [], [], [7], [31], [], [8], [26], [119], [91], [], [2]]
# ['< start >', 'a', 'child', 'playing', 'on', 'a', 'rope', 'net', '', '< end >']
# [[3], [1], [30], [29], [6], [1], [97], [], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'climbing', 'on', 'red', 'roping', '', '< end >']
# [[3], [1], [32], [16], [61], [6], [44], [], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'in', 'pink', 'climbs', 'a', 'rope', 'bridge', 'at', 'the', 'park', '', '< end >']
# [[3], [1], [32], [16], [4], [141], [], [1], [97], [], [15], [5], [123], [], [2]]
# ['< start >', 'a', 'small', 'child', 'grips', 'onto', 'the', 'red', 'ropes', 'at', 'the', 'playground', '', '< end >']
# [[3], [1], [46], [30], [], [], [5], [44], [], [15], [5], [], [], [2]]
# ['< start >', 'the', 'small', 'child', 'climbs', 'on', 'a', 'red', 'ropes', 'on', 'a', 'playground', '', '< end >']
# [[3], [5], [46], [30], [], [6], [1], [44], [], [6], [1], [], [], [2]]
# ['< start >', 'a', 'black', 'and', 'white', 'dog', 'is', 'running', 'in', 'a', 'grassy', 'garden', 'surrounded', 'by', 'a', 'white', 'fence', '', '< end >']
# [[3], [1], [17], [8], [19], [9], [7], [27], [4], [1], [109], [], [], [55], [1], [19], [], [], [2]]
# ['< start >', 'a', 'black', 'and', 'white', 'dog', 'is', 'running', 'through', 'the', 'grass', '', '< end >']
# [[3], [1], [17], [8], [19], [9], [7], [27], [37], [5], [49], [], [2]]
# ['< start >', 'a', 'boston', 'terrier', 'is', 'running', 'in', 'the', 'grass', '', '< end >']
# [[3], [1], [], [], [7], [27], [4], [5], [49], [], [2]]
# ['< start >', 'a', 'boston', 'terrier', 'is', 'running', 'on', 'lush', 'green', 'grass', 'in', 'front', 'of', 'a', 'white', 'fence', '', '< end >']
# [[3], [1], [], [], [7], [27], [6], [], [63], [49], [4], [38], [12], [1], [19], [], [], [2]]
# ['< start >', 'a', 'dog', 'runs', 'on', 'the', 'green', 'grass', 'near', 'a', 'wooden', 'fence', '', '< end >']
# [[3], [1], [9], [92], [6], [5], [63], [49], [57], [1], [], [], [], [2]]
# ['< start >', 'a', 'dog', 'shakes', 'its', 'head', 'near', 'the', 'shore', '', 'a', 'red', 'ball', 'next', 'to', 'it', '', '< end >']
# [[3], [1], [9], [], [80], [124], [57], [5], [143], [], [1], [44], [50], [68], [23], [103], [], [2]]
# ['< start >', 'a', 'white', 'dog', 'shakes', 'on', 'the', 'edge', 'of', 'a', 'beach', 'with', 'an', 'orange', 'ball', '', '< end >']
# [[3], [1], [19], [9], [], [6], [5], [], [12], [1], [36], [10], [26], [119], [50], [], [2]]
# ['< start >', 'dog', 'with', 'orange', 'ball', 'at', 'feet', '', 'stands', 'on', 'shore', 'shaking', 'off', 'water', '< end >']
# [[3], [9], [10], [119], [50], [15], [], [], [64], [6], [143], [], [76], [24], [2]]
# ['< start >', 'white', 'dog', 'playing', 'with', 'a', 'red', 'ball', 'on', 'the', 'shore', 'near', 'the', 'water', '', '< end >']
# [[3], [19], [9], [29], [10], [1], [44], [50], [6], [5], [143], [57], [5], [24], [], [2]]
# ['< start >', 'white', 'dog', 'with', 'brown', 'ears', 'standing', 'near', 'water', 'with', 'head', 'turned', 'to', 'one', 'side', '', '< end >']
# [[3], [19], [9], [10], [18], [], [53], [57], [24], [10], [124], [], [23], [70], [104], [], [2]]
# ['< start >', 'a', 'boy', 'smiles', 'in', 'front', 'of', 'a', 'stony', 'wall', 'in', 'a', 'city', '', '< end >']
# [[3], [1], [14], [], [4], [38], [12], [1], [], [93], [4], [1], [125], [], [2]]
# ['< start >', 'a', 'little', 'boy', 'is', 'standing', 'on', 'the', 'street', 'while', 'a', 'man', 'in', 'overalls', 'is', 'working', 'on', 'a', 'stone', 'wall', '', '< end >']
# [[3], [1], [32], [14], [7], [53], [6], [5], [60], [34], [1], [11], [4], [], [7], [], [6], [1], [], [93], [], [2]]
# ['< start >', 'a', 'young', 'boy', 'runs', 'aross', 'the', 'street', '', '< end >']
# [[3], [1], [21], [14], [92], [], [5], [60], [], [2]]
# ['< start >', 'a', 'young', 'child', 'is', 'walking', 'on', 'a', 'stone', 'paved', 'street', 'with', 'a', 'metal', 'pole', 'and', 'a', 'man', 'behind', 'him', '', '< end >']
# [[3], [1], [21], [30], [7], [77], [6], [1], [], [], [60], [10], [1], [], [], [8], [1], [11], [100], [118], [], [2]]
# ['< start >', 'smiling', 'boy', 'in', 'white', 'shirt', 'and', 'blue', 'jeans', 'in', 'front', 'of', 'rock', 'wall', 'with', 'man', 'in', 'overalls', 'behind', 'him', '', '< end >']
# [[3], [144], [14], [4], [19], [41], [8], [28], [], [4], [38], [12], [58], [93], [10], [11], [4], [], [100], [118], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'leaps', 'over', 'a', 'log', '', '< end >']
# [[3], [1], [17], [9], [145], [83], [1], [], [], [2]]
# ['< start >', 'a', 'grey', 'dog', 'is', 'leaping', 'over', 'a', 'fallen', 'tree', '', '< end >']
# [[3], [1], [], [9], [7], [], [83], [1], [], [], [], [2]]
# ['< start >', 'a', 'large', 'black', 'dog', 'leaps', 'a', 'fallen', 'log', '', '< end >']
# [[3], [1], [62], [17], [9], [145], [1], [], [], [], [2]]
# ['< start >', 'a', 'mottled', 'black', 'and', 'grey', 'dog', 'in', 'a', 'blue', 'collar', 'jumping', 'over', 'a', 'fallen', 'tree', '', '< end >']
# [[3], [1], [], [17], [8], [], [9], [4], [1], [28], [], [40], [83], [1], [], [], [], [2]]
# ['< start >', 'the', 'black', 'dog', 'jumped', 'the', 'tree', 'stump', '', '< end >']
# [[3], [5], [17], [9], [], [5], [], [], [], [2]]
# ['< start >', 'a', 'brown', 'and', 'white', 'dog', 'is', 'running', 'through', 'the', 'snow', '', '< end >']
# [[3], [1], [18], [8], [19], [9], [7], [27], [37], [5], [59], [], [2]]
# ['< start >', 'a', 'dog', 'is', 'running', 'in', 'the', 'snow', '< end >']
# [[3], [1], [9], [7], [27], [4], [5], [59], [2]]
# ['< start >', 'a', 'dog', 'running', 'through', 'snow', '', '< end >']
# [[3], [1], [9], [27], [37], [59], [], [2]]
# ['< start >', 'a', 'white', 'and', 'brown', 'dog', 'is', 'running', 'through', 'a', 'snow', 'covered', 'field', '', '< end >']
# [[3], [1], [19], [8], [18], [9], [7], [27], [37], [1], [59], [96], [45], [], [2]]
# ['< start >', 'the', 'white', 'and', 'brown', 'dog', 'is', 'running', 'over', 'the', 'surface', 'of', 'the', 'snow', '', '< end >']
# [[3], [5], [19], [8], [18], [9], [7], [27], [83], [5], [], [12], [5], [59], [], [2]]
# ['< start >', 'a', 'man', 'in', 'a', 'hat', 'is', 'displaying', 'pictures', 'next', 'to', 'a', 'skier', 'in', 'a', 'blue', 'hat', '', '< end >']
# [[3], [1], [11], [4], [1], [91], [7], [], [], [68], [23], [1], [], [4], [1], [28], [91], [], [2]]
# ['< start >', 'a', 'man', 'skis', 'past', 'another', 'man', 'displaying', 'paintings', 'in', 'the', 'snow', '', '< end >']
# [[3], [1], [11], [], [], [73], [11], [], [], [4], [5], [59], [], [2]]
# ['< start >', 'a', 'person', 'wearing', 'skis', 'looking', 'at', 'framed', 'pictures', 'set', 'up', 'in', 'the', 'snow', '', '< end >']
# [[3], [1], [54], [31], [], [108], [15], [], [], [], [51], [4], [5], [59], [], [2]]
# ['< start >', 'a', 'skier', 'looks', 'at', 'framed', 'pictures', 'in', 'the', 'snow', 'next', 'to', 'trees', '', '< end >']
# [[3], [1], [], [126], [15], [], [], [4], [5], [59], [68], [23], [], [], [2]]
# ['< start >', 'man', 'on', 'skis', 'looking', 'at', 'artwork', 'for', 'sale', 'in', 'the', 'snow', '< end >']
# [[3], [11], [6], [], [108], [15], [], [98], [], [4], [5], [59], [2]]
# ['< start >', 'a', 'collage', 'of', 'one', 'person', 'climbing', 'a', 'cliff', '', '< end >']
# [[3], [1], [], [12], [70], [54], [61], [1], [], [], [2]]
# ['< start >', 'a', 'group', 'of', 'people', 'are', 'rock', 'climbing', 'on', 'a', 'rock', 'climbing', 'wall', '', '< end >']
# [[3], [1], [81], [12], [25], [22], [58], [61], [6], [1], [58], [61], [93], [], [2]]
# ['< start >', 'a', 'group', 'of', 'people', 'climbing', 'a', 'rock', 'while', 'one', 'man', 'belays', '< end >']
# [[3], [1], [81], [12], [25], [61], [1], [58], [34], [70], [11], [], [2]]
# ['< start >', 'seven', 'climbers', 'are', 'ascending', 'a', 'rock', 'face', 'whilst', 'another', 'man', 'stands', 'holding', 'the', 'rope', '', '< end >']
# [[3], [], [], [22], [], [1], [58], [127], [], [73], [11], [64], [66], [5], [97], [], [2]]
# ['< start >', 'several', 'climbers', 'in', 'a', 'row', 'are', 'climbing', 'the', 'rock', 'while', 'the', 'man', 'in', 'red', 'watches', 'and', 'holds', 'the', 'line', '', '< end >']
# [[3], [], [], [4], [1], [], [22], [61], [5], [58], [34], [5], [11], [4], [44], [], [8], [146], [5], [], [], [2]]
# ['< start >', 'a', 'brown', 'dog', 'chases', 'the', 'water', 'from', 'a', 'sprinkler', 'on', 'a', 'lawn', '', '< end >']
# [[3], [1], [18], [9], [], [5], [24], [84], [1], [], [6], [1], [], [], [2]]
# ['< start >', 'a', 'brown', 'dog', 'plays', 'with', 'the', 'hose', '', '< end >']
# [[3], [1], [18], [9], [89], [10], [5], [], [], [2]]
# ['< start >', 'a', 'brown', 'dog', 'running', 'on', 'a', 'lawn', 'near', 'a', 'garden', 'hose', '< end >']
# [[3], [1], [18], [9], [27], [6], [1], [], [57], [1], [], [], [2]]
# ['< start >', 'a', 'dog', 'is', 'playing', 'with', 'a', 'hose', '', '< end >']
# [[3], [1], [9], [7], [29], [10], [1], [], [], [2]]
# ['< start >', 'large', 'brown', 'dog', 'running', 'away', 'from', 'the', 'sprinkler', 'in', 'the', 'grass', '', '< end >']
# [[3], [62], [18], [9], [27], [], [84], [5], [], [4], [5], [49], [], [2]]
# ['< start >', 'a', 'dog', 'prepares', 'to', 'catch', 'a', 'thrown', 'object', 'in', 'a', 'field', 'with', 'nearby', 'cars', '', '< end >']
# [[3], [1], [9], [], [23], [72], [1], [], [], [4], [1], [45], [10], [], [], [], [2]]
# ['< start >', 'a', 'white', 'dog', 'is', 'about', 'to', 'catch', 'a', 'yellow', 'ball', 'in', 'its', 'mouth', '', '< end >']
# [[3], [1], [19], [9], [7], [], [23], [72], [1], [56], [50], [4], [80], [74], [], [2]]
# ['< start >', 'a', 'white', 'dog', 'is', 'about', 'to', 'catch', 'a', 'yellow', 'dog', 'toy', '', '< end >']
# [[3], [1], [19], [9], [7], [], [23], [72], [1], [56], [9], [52], [], [2]]
# ['< start >', 'a', 'white', 'dog', 'is', 'ready', 'to', 'catch', 'a', 'yellow', 'ball', 'flying', 'through', 'the', 'air', '', '< end >']
# [[3], [1], [19], [9], [7], [], [23], [72], [1], [56], [50], [], [37], [5], [67], [], [2]]
# ['< start >', 'a', 'white', 'dog', 'running', 'after', 'a', 'yellow', 'ball', '< end >']
# [[3], [1], [19], [9], [27], [], [1], [56], [50], [2]]
# ['< start >', 'a', 'black', 'and', 'white', 'dog', 'jumping', 'in', 'the', 'air', 'to', 'get', 'a', 'toy', '', '< end >']
# [[3], [1], [17], [8], [19], [9], [40], [4], [5], [67], [23], [], [1], [52], [], [2]]
# ['< start >', 'a', 'black', 'and', 'white', 'dog', 'jumps', 'up', 'towards', 'a', 'yellow', 'toy', '', '< end >']
# [[3], [1], [17], [8], [19], [9], [85], [51], [], [1], [56], [52], [], [2]]
# ['< start >', 'a', 'dog', 'leaps', 'to', 'catch', 'a', 'ball', 'in', 'a', 'field', '', '< end >']
# [[3], [1], [9], [145], [23], [72], [1], [50], [4], [1], [45], [], [2]]
# ['< start >', 'a', 'white', 'dog', 'is', 'trying', 'to', 'catch', 'a', 'ball', 'in', 'midair', 'over', 'a', 'grassy', 'field', '', '< end >']
# [[3], [1], [19], [9], [7], [], [23], [72], [1], [50], [4], [], [83], [1], [109], [45], [], [2]]
# ['< start >', 'the', 'white', 'dog', 'is', 'playing', 'in', 'a', 'green', 'field', 'with', 'a', 'yellow', 'toy', '', '< end >']
# [[3], [5], [19], [9], [7], [29], [4], [1], [63], [45], [10], [1], [56], [52], [], [2]]
# ['< start >', 'a', 'child', 'and', 'a', 'woman', 'are', 'at', 'waters', 'edge', 'in', 'a', 'big', 'city', '', '< end >']
# [[3], [1], [30], [8], [1], [20], [22], [15], [], [], [4], [1], [], [125], [], [2]]
# ['< start >', 'a', 'large', 'lake', 'with', 'a', 'lone', 'duck', 'swimming', 'in', 'it', 'with', 'several', 'people', 'around', 'the', 'edge', 'of', 'it', '', '< end >']
# [[3], [1], [62], [128], [10], [1], [], [], [101], [4], [103], [10], [], [25], [], [5], [], [12], [103], [], [2]]
# ['< start >', 'a', 'little', 'boy', 'at', 'a', 'lake', 'watching', 'a', 'duck', '', '< end >']
# [[3], [1], [32], [14], [15], [1], [128], [147], [1], [], [], [2]]
# ['< start >', 'a', 'young', 'boy', 'waves', 'his', 'hand', 'at', 'the', 'duck', 'in', 'the', 'water', 'surrounded', 'by', 'a', 'green', 'park', '', '< end >']
# [[3], [1], [21], [14], [], [35], [148], [15], [5], [], [4], [5], [24], [], [55], [1], [63], [123], [], [2]]
# ['< start >', 'two', 'people', 'are', 'at', 'the', 'edge', 'of', 'a', 'lake', '', 'facing', 'the', 'water', 'and', 'the', 'city', 'skyline', '', '< end >']
# [[3], [13], [25], [22], [15], [5], [], [12], [1], [128], [], [], [5], [24], [8], [5], [125], [], [], [2]]
# ['< start >', 'a', 'couple', 'and', 'an', 'infant', '', 'being', 'held', 'by', 'the', 'male', '', 'sitting', 'next', 'to', 'a', 'pond', 'with', 'a', 'near', 'by', 'stroller', '', '< end >']
# [[3], [1], [], [8], [26], [], [], [], [], [55], [5], [], [], [39], [68], [23], [1], [], [10], [1], [57], [55], [], [], [2]]
# ['< start >', 'a', 'couple', 'sit', 'on', 'the', 'grass', 'with', 'a', 'baby', 'and', 'stroller', '', '< end >']
# [[3], [1], [], [99], [6], [5], [49], [10], [1], [113], [8], [], [], [2]]
# ['< start >', 'a', 'couple', 'with', 'their', 'newborn', 'baby', 'sitting', 'under', 'a', 'tree', 'facing', 'a', 'lake', '', '< end >']
# [[3], [1], [], [10], [129], [], [113], [39], [], [1], [], [], [1], [128], [], [2]]
# ['< start >', 'a', 'man', 'and', 'woman', 'care', 'for', 'an', 'infant', 'along', 'the', 'side', 'of', 'a', 'body', 'of', 'water', '', '< end >']
# [[3], [1], [11], [8], [20], [], [98], [26], [], [114], [5], [104], [12], [1], [], [12], [24], [], [2]]
# ['< start >', 'couple', 'with', 'a', 'baby', 'sit', 'outdoors', 'next', 'to', 'their', 'stroller', '', '< end >']
# [[3], [], [10], [1], [113], [99], [], [68], [23], [129], [], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'running', 'in', 'the', 'surf', '', '< end >']
# [[3], [1], [17], [9], [27], [4], [5], [], [], [2]]
# ['< start >', 'a', 'black', 'lab', 'with', 'tags', 'frolicks', 'in', 'the', 'water', '', '< end >']
# [[3], [1], [17], [], [10], [], [], [4], [5], [24], [], [2]]
# ['< start >', 'a', 'dog', 'splashes', 'in', 'the', 'water', '< end >']
# [[3], [1], [9], [], [4], [5], [24], [2]]
# ['< start >', 'the', 'black', 'dog', 'runs', 'through', 'the', 'water', '', '< end >']
# [[3], [5], [17], [9], [92], [37], [5], [24], [], [2]]
# ['< start >', 'this', 'is', 'a', 'black', 'dog', 'splashing', 'in', 'the', 'water', '', '< end >']
# [[3], [], [7], [1], [17], [9], [], [4], [5], [24], [], [2]]
# ['< start >', 'a', 'man', 'drilling', 'a', 'hole', 'in', 'the', 'ice', '', '< end >']
# [[3], [1], [11], [], [1], [], [4], [5], [102], [], [2]]
# ['< start >', 'a', 'man', 'is', 'drilling', 'through', 'the', 'frozen', 'ice', 'of', 'a', 'pond', '', '< end >']
# [[3], [1], [11], [7], [], [37], [5], [], [102], [12], [1], [], [], [2]]
# ['< start >', 'a', 'person', 'in', 'the', 'snow', 'drilling', 'a', 'hole', 'in', 'the', 'ice', '', '< end >']
# [[3], [1], [54], [4], [5], [59], [], [1], [], [4], [5], [102], [], [2]]
# ['< start >', 'a', 'person', 'standing', 'on', 'a', 'frozen', 'lake', '', '< end >']
# [[3], [1], [54], [53], [6], [1], [], [128], [], [2]]
# ['< start >', 'two', 'men', 'are', 'ice', 'fishing', '', '< end >']
# [[3], [13], [82], [22], [102], [], [], [2]]
# ['< start >', 'two', 'different', 'breeds', 'of', 'brown', 'and', 'white', 'dogs', 'play', 'on', 'the', 'beach', '', '< end >']
# [[3], [13], [], [], [12], [18], [8], [19], [33], [149], [6], [5], [36], [], [2]]
# ['< start >', 'two', 'dogs', 'are', 'making', 'a', 'turn', 'on', 'a', 'soft', 'sand', 'beach', '', '< end >']
# [[3], [13], [33], [22], [], [1], [], [6], [1], [], [115], [36], [], [2]]
# ['< start >', 'two', 'dogs', 'playing', 'in', 'the', 'sand', 'at', 'the', 'beach', '', '< end >']
# [[3], [13], [33], [29], [4], [5], [115], [15], [5], [36], [], [2]]
# ['< start >', 'two', 'dogs', 'playing', 'together', 'on', 'a', 'beach', '', '< end >']
# [[3], [13], [33], [29], [], [6], [1], [36], [], [2]]
# ['< start >', 'two', 'large', 'tan', 'dogs', 'play', 'along', 'a', 'sandy', 'beach', '', '< end >']
# [[3], [13], [62], [135], [33], [149], [114], [1], [], [36], [], [2]]
# ['< start >', 'a', 'man', 'uses', 'ice', 'picks', 'and', 'crampons', 'to', 'scale', 'ice', '', '< end >']
# [[3], [1], [11], [], [102], [], [8], [], [23], [], [102], [], [2]]
# ['< start >', 'an', 'ice', 'climber', 'in', 'a', 'blue', 'jacket', 'and', 'black', 'pants', 'is', 'scaling', 'a', 'frozen', 'ice', 'wall', '', '< end >']
# [[3], [26], [102], [], [4], [1], [28], [105], [8], [17], [], [7], [], [1], [], [102], [93], [], [2]]
# ['< start >', 'an', 'ice', 'climber', 'scaling', 'a', 'frozen', 'waterfall', '', '< end >']
# [[3], [26], [102], [], [], [1], [], [], [], [2]]
# ['< start >', 'a', 'person', 'in', 'blue', 'and', 'red', 'ice', 'climbing', 'with', 'two', 'picks', '', '< end >']
# [[3], [1], [54], [4], [28], [8], [44], [102], [61], [10], [13], [], [], [2]]
# ['< start >', 'climber', 'climbing', 'an', 'ice', 'wall', '< end >']
# [[3], [], [61], [26], [102], [93], [2]]
# ['< start >', 'a', 'black', 'dog', 'carries', 'a', 'green', 'toy', 'in', 'his', 'mouth', 'as', 'he', 'walks', 'through', 'the', 'grass', '', '< end >']
# [[3], [1], [17], [9], [], [1], [63], [52], [4], [35], [74], [110], [], [106], [37], [5], [49], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'carrying', 'something', 'through', 'the', 'grass', '', '< end >']
# [[3], [1], [17], [9], [], [], [37], [5], [49], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'has', 'a', 'blue', 'toy', 'in', 'its', 'mouth', '', '< end >']
# [[3], [1], [17], [9], [], [1], [28], [52], [4], [80], [74], [], [2]]
# ['< start >', 'a', 'dog', 'in', 'grass', 'with', 'a', 'blue', 'item', 'in', 'his', 'mouth', '', '< end >']
# [[3], [1], [9], [4], [49], [10], [1], [28], [], [4], [35], [74], [], [2]]
# ['< start >', 'a', 'wet', 'black', 'dog', 'is', 'carrying', 'a', 'green', 'toy', 'through', 'the', 'grass', '', '< end >']
# [[3], [1], [], [17], [9], [7], [], [1], [63], [52], [37], [5], [49], [], [2]]
# ['< start >', 'a', 'man', 'and', 'a', 'baby', 'are', 'in', 'a', 'yellow', 'kayak', 'on', 'water', '', '< end >']
# [[3], [1], [11], [8], [1], [113], [22], [4], [1], [56], [], [6], [24], [], [2]]
# ['< start >', 'a', 'man', 'and', 'a', 'little', 'boy', 'in', 'blue', 'life', 'jackets', 'are', 'rowing', 'a', 'yellow', 'canoe', '', '< end >']
# [[3], [1], [11], [8], [1], [32], [14], [4], [28], [], [], [22], [], [1], [56], [], [], [2]]
# ['< start >', 'a', 'man', 'and', 'child', 'kayak', 'through', 'gentle', 'waters', '', '< end >']
# [[3], [1], [11], [8], [30], [], [37], [], [], [], [2]]
# ['< start >', 'a', 'man', 'and', 'young', 'boy', 'ride', 'in', 'a', 'yellow', 'kayak', '', '< end >']
# [[3], [1], [11], [8], [21], [14], [], [4], [1], [56], [], [], [2]]
# ['< start >', 'man', 'and', 'child', 'in', 'yellow', 'kayak', '< end >']
# [[3], [11], [8], [30], [4], [56], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'and', 'a', 'brown', 'dog', 'are', 'jumping', 'up', 'to', 'catch', 'a', 'red', 'toy', '', '< end >']
# [[3], [1], [17], [9], [8], [1], [18], [9], [22], [40], [51], [23], [72], [1], [44], [52], [], [2]]
# ['< start >', 'a', 'black', 'dog', 'and', 'a', 'brown', 'dog', 'play', 'with', 'a', 'red', 'toy', 'on', 'a', 'courtyard', '', '< end >']
# [[3], [1], [17], [9], [8], [1], [18], [9], [149], [10], [1], [44], [52], [6], [1], [], [], [2]]
# ['< start >', 'a', 'brown', 'and', 'black', 'lab', 'are', 'outside', 'and', 'the', 'black', 'lab', 'is', 'catching', 'a', 'toy', 'in', 'its', 'mouth', '', '< end >']
# [[3], [1], [18], [8], [17], [], [22], [71], [8], [5], [17], [], [7], [], [1], [52], [4], [80], [74], [], [2]]
# ['< start >', 'black', 'dog', 'snaps', 'at', 'red', 'and', 'black', 'object', 'as', 'brown', 'dog', 'lunges', '', '< end >']
# [[3], [17], [9], [], [15], [44], [8], [17], [], [110], [18], [9], [], [], [2]]
# ['< start >', 'the', 'chocolate', 'lab', 'jumps', 'too', 'late', 'to', 'get', 'the', 'toy', 'as', 'the', 'black', 'lab', 'captures', 'it', 'in', 'the', 'driveway', '', '< end >']
# [[3], [5], [], [], [85], [], [], [23], [], [5], [52], [110], [5], [17], [], [], [103], [4], [5], [], [], [2]]
# ['< start >', 'a', 'boy', 'with', 'a', 'stick', 'kneeling', 'in', 'front', 'of', 'a', 'goalie', 'net', '< end >']
# [[3], [1], [14], [10], [1], [], [], [4], [38], [12], [1], [], [], [2]]
# ['< start >', 'a', 'child', 'in', 'a', 'red', 'jacket', 'playing', 'street', 'hockey', 'guarding', 'a', 'goal', '', '< end >']
# [[3], [1], [30], [4], [1], [44], [105], [29], [60], [], [], [1], [], [], [2]]
# ['< start >', 'a', 'young', 'kid', 'playing', 'the', 'goalie', 'in', 'a', 'hockey', 'rink', '', '< end >']
# [[3], [1], [21], [], [29], [5], [], [4], [1], [], [], [], [2]]
# ['< start >', 'a', 'young', 'male', 'kneeling', 'in', 'front', 'of', 'a', 'hockey', 'goal', 'with', 'a', 'hockey', 'stick', 'in', 'his', 'right', 'hand', '', '< end >']
# [[3], [1], [21], [], [], [4], [38], [12], [1], [], [], [10], [1], [], [], [4], [35], [], [148], [], [2]]
# ['< start >', 'hockey', 'goalie', 'boy', 'in', 'red', 'jacket', 'crouches', 'by', 'goal', '', 'with', 'stick', '', '< end >']
# [[3], [], [], [14], [4], [44], [105], [], [55], [], [], [10], [], [], [2]]
# ['< start >', 'a', 'man', 'in', 'black', 'is', 'sitting', 'next', 'to', 'a', 'modern', 'art', 'structure', 'in', 'front', 'of', 'a', 'glass', 'building', '', '< end >']
# [[3], [1], [11], [4], [17], [7], [39], [68], [23], [1], [], [], [], [4], [38], [12], [1], [], [116], [], [2]]
# ['< start >', 'a', 'man', 'sits', 'and', 'reads', 'a', 'newspaper', 'by', 'a', 'sculpture', 'outside', 'of', 'an', 'office', 'building', '', '< end >']
# [[3], [1], [11], [65], [8], [], [1], [], [55], [1], [], [71], [12], [26], [], [116], [], [2]]
# ['< start >', 'a', 'man', 'sits', 'near', 'a', 'large', 'statue', '', '< end >']
# [[3], [1], [11], [65], [57], [1], [62], [], [], [2]]
# ['< start >', 'a', 'man', 'sitting', 'in', 'front', 'of', 'a', 'metal', 'sculpture', 'in', 'front', 'of', 'a', 'building', '', '< end >']
# [[3], [1], [11], [39], [4], [38], [12], [1], [], [], [4], [38], [12], [1], [116], [], [2]]
# ['< start >', 'the', 'man', 'with', 'the', 'backpack', 'is', 'sitting', 'in', 'a', 'buildings', 'courtyard', 'in', 'front', 'of', 'an', 'art', 'sculpture', 'reading', '', '< end >']
# [[3], [5], [11], [10], [5], [], [7], [39], [4], [1], [], [], [4], [38], [12], [26], [], [], [], [], [2]]
# ['< start >', 'a', 'tent', 'is', 'being', 'set', 'up', 'on', 'the', 'ice', '', '< end >']
# [[3], [1], [], [7], [], [], [51], [6], [5], [102], [], [2]]
# ['< start >', 'two', 'men', 'are', 'about', 'to', 'enter', 'an', 'ice', 'fishing', 'tent', 'on', 'a', 'snow', 'covered', 'lake', '', '< end >']
# [[3], [13], [82], [22], [], [23], [], [26], [102], [], [], [6], [1], [59], [96], [128], [], [2]]
# ['< start >', 'two', 'men', 'setting', 'up', 'a', 'blue', 'ice', 'fishing', 'hut', 'on', 'an', 'iced', 'over', 'lake', '< end >']
# [[3], [13], [82], [], [51], [1], [28], [102], [], [], [6], [26], [], [83], [128], [2]]
# ['< start >', 'two', 'men', '', 'standing', 'on', 'an', 'ice', '', 'looking', 'into', 'something', 'covered', 'with', 'a', 'blue', 'tarp', '', '< end >']
# [[3], [13], [82], [], [53], [6], [26], [102], [], [108], [42], [], [96], [10], [1], [28], [], [], [2]]
# ['< start >', 'two', 'people', 'standing', 'outside', 'a', 'blue', 'tent', 'structure', 'on', 'a', 'snowy', 'surface', '', '< end >']
# [[3], [13], [25], [53], [71], [1], [28], [], [], [6], [1], [], [], [], [2]]
# ['< start >', 'a', 'woman', 'crouches', 'near', 'three', 'dogs', 'in', 'a', 'field', '', '< end >']
# [[3], [1], [20], [], [57], [43], [33], [4], [1], [45], [], [2]]
# ['< start >', 'three', 'dogs', 'are', 'playing', 'on', 'grassy', 'hill', 'with', 'a', 'blue', 'sky', '', '< end >']
# [[3], [43], [33], [22], [29], [6], [109], [120], [10], [1], [28], [], [], [2]]
# ['< start >', 'three', 'dogs', 'are', 'standing', 'in', 'the', 'grass', 'and', 'a', 'person', 'is', 'sitting', 'next', 'to', 'them', '< end >']
# [[3], [43], [33], [22], [53], [4], [5], [49], [8], [1], [54], [7], [39], [68], [23], [], [2]]
# ['< start >', 'three', 'dogs', 'on', 'a', 'grassy', 'hill', '< end >']
# [[3], [43], [33], [6], [1], [109], [120], [2]]
# ['< start >', 'three', 'dogs', 'stand', 'in', 'a', 'grassy', 'field', 'while', 'a', 'person', 'kneels', 'nearby', '', '< end >']
# [[3], [43], [33], [150], [4], [1], [109], [45], [34], [1], [54], [], [], [], [2]]
# ['< start >', 'a', 'man', 'is', 'standing', 'in', 'front', 'of', 'a', 'skyscraper', '< end >']
# [[3], [1], [11], [7], [53], [4], [38], [12], [1], [], [2]]
# ['< start >', 'a', 'man', 'stands', 'in', 'front', 'of', 'a', 'skyscraper', '', '< end >']
# [[3], [1], [11], [64], [4], [38], [12], [1], [], [], [2]]
# ['< start >', 'a', 'man', 'stands', 'in', 'front', 'of', 'a', 'very', 'tall', 'building', '', '< end >']
# [[3], [1], [11], [64], [4], [38], [12], [1], [], [], [116], [], [2]]
# ['< start >', 'behind', 'the', 'man', 'in', 'a', 'red', 'shirt', 'stands', 'a', 'large', 'skyscraper', '', '< end >']
# [[3], [100], [5], [11], [4], [1], [44], [41], [64], [1], [62], [], [], [2]]
# ['< start >', 'there', 'is', 'a', 'skyscraper', 'in', 'the', 'distance', 'with', 'a', 'man', 'walking', 'in', 'front', 'of', 'the', 'camera', '', '< end >']
# [[3], [134], [7], [1], [], [4], [5], [], [10], [1], [11], [77], [4], [38], [12], [5], [86], [], [2]]
# ['< start >', 'a', 'boy', 'bites', 'hard', 'into', 'a', 'treat', 'while', 'he', 'sits', 'outside', '', '< end >']
# [[3], [1], [14], [], [], [42], [1], [], [34], [], [65], [71], [], [2]]
# ['< start >', 'a', 'child', 'biting', 'into', 'a', 'baked', 'good', '', '< end >']
# [[3], [1], [30], [], [42], [1], [], [], [], [2]]
# ['< start >', 'a', 'small', 'boy', 'putting', 'something', 'in', 'his', 'mouth', 'with', 'both', 'hands', '', '< end >']
# [[3], [1], [46], [14], [], [], [4], [35], [74], [10], [], [], [], [2]]
# ['< start >', 'the', 'boy', 'eats', 'his', 'food', 'outside', 'at', 'the', 'table', '', '< end >']
# [[3], [5], [14], [], [35], [], [71], [15], [5], [151], [], [2]]
# ['< start >', 'the', 'boy', 'is', 'eating', 'pizza', 'over', 'a', 'tin', 'dish', '', '< end >']
# [[3], [5], [14], [7], [], [], [83], [1], [], [], [], [2]]
# ['< start >', 'people', 'sit', 'on', 'the', 'mountainside', 'and', 'check', 'out', 'the', 'view', '', '< end >']
# [[3], [25], [99], [6], [5], [], [8], [], [87], [5], [], [], [2]]
# ['< start >', 'three', 'people', 'are', 'on', 'a', 'hilltop', 'overlooking', 'a', 'green', 'valley', '', '< end >']
# [[3], [43], [25], [22], [6], [1], [], [], [1], [63], [], [], [2]]
# ['< start >', 'three', 'people', 'hang', 'out', 'on', 'top', 'of', 'a', 'big', 'hill', '', '< end >']
# [[3], [43], [25], [], [87], [6], [], [12], [1], [], [120], [], [2]]
# ['< start >', 'three', 'people', 'overlook', 'a', 'green', 'valley', '', '< end >']
# [[3], [43], [25], [], [1], [63], [], [], [2]]
# ['< start >', 'three', 'people', 'rest', 'on', 'a', 'ledge', 'above', 'the', 'moutains', '', '< end >']
# [[3], [43], [25], [], [6], [1], [], [], [5], [], [], [2]]
# ['< start >', 'a', 'boy', 'in', 'a', 'green', 'shirt', 'is', 'looking', 'down', 'at', 'many', 'inflatable', 'boats', '', '< end >']
# [[3], [1], [14], [4], [1], [63], [41], [7], [108], [47], [15], [], [], [], [], [2]]
# ['< start >', 'a', 'boy', 'in', 'a', 'green', 'shirt', 'watches', 'kayakers', '', '< end >']
# [[3], [1], [14], [4], [1], [63], [41], [], [], [], [2]]
# ['< start >', 'a', 'boy', 'looks', 'over', 'a', 'railing', 'at', 'the', 'many', 'boats', 'and', 'rafts', 'below', 'in', 'the', 'water', '', '< end >']
# [[3], [1], [14], [126], [83], [1], [], [15], [5], [], [], [8], [], [], [4], [5], [24], [], [2]]
# ['< start >', 'a', 'young', 'boy', 'overlooking', 'a', 'crowd', 'of', 'inflatable', 'boats', '', '< end >']
# [[3], [1], [21], [14], [], [1], [], [12], [], [], [], [2]]
# ['< start >', 'a', 'young', 'boy', 'wearing', 'a', 'jersey', 'looks', 'down', 'over', 'a', 'ledge', 'at', 'many', 'boats', 'in', 'the', 'water', '', '< end >']
# [[3], [1], [21], [14], [31], [1], [], [126], [47], [83], [1], [], [15], [], [], [4], [5], [24], [], [2]]
# ['< start >', 'a', 'man', 'and', 'woman', 'pose', 'for', 'the', 'camera', 'while', 'another', 'man', 'looks', 'on', '', '< end >']
# [[3], [1], [11], [8], [20], [], [98], [5], [86], [34], [73], [11], [126], [6], [], [2]]
# ['< start >', 'a', 'man', 'is', 'holding', 'the', 'hand', 'of', 'a', 'woman', 'up', 'to', 'his', 'mouth', 'in', 'front', 'of', 'some', 'buildings', 'while', 'another', 'man', 'looks', 'on', '', '< end >']
# [[3], [1], [11], [7], [66], [5], [148], [12], [1], [20], [51], [23], [35], [74], [4], [38], [12], [], [], [34], [73], [11], [126], [6], [], [2]]
# ['< start >', 'a', 'multiracial', 'couple', 'posing', 'for', 'a', 'picture', '< end >']
# [[3], [1], [], [], [], [98], [1], [130], [2]]
# ['< start >', 'asian', 'man', 'and', 'blond', 'woman', 'holding', 'hands', 'outdoors', '', 'man', 'in', 'background', 'watches', '', '< end >']
# [[3], [], [11], [8], [152], [20], [66], [], [], [], [11], [4], [], [], [], [2]]
# ['< start >', 'guy', 'in', 'blue', 'shirt', 'biting', 'hand', 'of', 'girl', 'in', 'black', 'striped', 'jacket', 'while', 'another', 'guy', 'watches', '< end >']
# [[3], [], [4], [28], [41], [], [148], [12], [16], [4], [17], [], [105], [34], [73], [], [], [2]]
# ['< start >', 'a', 'person', 'eats', 'takeout', 'while', 'watching', 'a', 'small', 'television', '', '< end >']
# [[3], [1], [54], [], [], [34], [147], [1], [46], [], [], [2]]
# ['< start >', 'a', 'person', 'sits', 'on', 'the', 'floor', 'and', 'eats', 'in', 'front', 'of', 'a', 'television', '', '< end >']
# [[3], [1], [54], [65], [6], [5], [], [8], [], [4], [38], [12], [1], [], [], [2]]
# ['< start >', 'a', 'television', 'with', 'a', 'picture', 'of', 'a', 'girl', 'on', 'it', '', '< end >']
# [[3], [1], [], [10], [1], [130], [12], [1], [16], [6], [103], [], [2]]
# ['< start >', 'a', 'young', 'man', 'sits', 'on', 'the', 'floor', 'by', 'the', 'television', 'with', 'a', 'fast', 'food', 'meal', 'in', 'front', 'of', 'him', '', '< end >']
# [[3], [1], [21], [11], [65], [6], [5], [], [55], [5], [], [10], [1], [], [], [], [4], [38], [12], [118], [], [2]]
# ['< start >', 'someone', 'is', 'laying', 'in', 'front', 'of', 'the', 'tv', 'eating', 'food', '', '< end >']
# [[3], [], [7], [], [4], [38], [12], [5], [], [], [], [], [2]]
# ['< start >', 'a', 'couple', 'of', 'several', 'people', 'sitting', 'on', 'a', 'ledge', 'overlooking', 'the', 'beach', '< end >']
# [[3], [1], [], [12], [], [25], [39], [6], [1], [], [], [5], [36], [2]]
# ['< start >', 'a', 'group', 'of', 'people', 'sit', 'on', 'a', 'wall', 'at', 'the', 'beach', '', '< end >']
# [[3], [1], [81], [12], [25], [99], [6], [1], [93], [15], [5], [36], [], [2]]
# ['< start >', 'a', 'group', 'of', 'teens', 'sit', 'on', 'a', 'wall', 'by', 'a', 'beach', '', '< end >']
# [[3], [1], [81], [12], [], [99], [6], [1], [93], [55], [1], [36], [], [2]]
# ['< start >', 'crowd', 'of', 'people', 'at', 'the', 'beach', '', '< end >']
# [[3], [], [12], [25], [15], [5], [36], [], [2]]
# ['< start >', 'several', 'young', 'people', 'sitting', 'on', 'a', 'rail', 'above', 'a', 'crowded', 'beach', '', '< end >']
# [[3], [], [21], [25], [39], [6], [1], [], [], [1], [], [36], [], [2]]
# ['< start >', 'a', 'boy', 'takes', 'a', 'jump', 'on', 'his', 'skateboard', 'while', 'another', 'boy', 'with', 'a', 'skateboard', 'watches', '', '< end >']
# [[3], [1], [14], [], [1], [], [6], [35], [], [34], [73], [14], [10], [1], [], [], [], [2]]
# ['< start >', 'a', 'child', 'is', 'performing', 'a', 'skateboard', 'trick', 'while', 'another', 'child', 'with', 'a', 'skateboard', 'leans', 'on', 'a', 'wall', '', '< end >']
# [[3], [1], [30], [7], [], [1], [], [], [34], [73], [30], [10], [1], [], [], [6], [1], [93], [], [2]]
# ['< start >', 'a', 'little', 'boy', 'skateboarder', 'is', 'doing', 'a', 'trick', 'on', 'his', 'board', 'while', 'another', 'young', 'skateboarder', 'watches', '', '< end >']
# [[3], [1], [32], [14], [], [7], [], [1], [], [6], [35], [], [34], [73], [21], [], [], [], [2]]
# ['< start >', 'a', 'young', 'boy', 'skateboarder', 'jumping', 'on', 'a', 'platform', 'on', 'a', 'skateboard', '', '< end >']
# [[3], [1], [21], [14], [], [40], [6], [1], [], [6], [1], [], [], [2]]
# ['< start >', 'two', 'skateboarders', '', '< end >']
# [[3], [13], [], [], [2]]
# ['< start >', 'a', 'girl', 'paddling', 'down', 'a', 'large', 'river', '', 'as', 'seen', 'from', 'behind', 'her', '', '< end >']
# [[3], [1], [16], [], [47], [1], [62], [], [], [110], [], [84], [100], [69], [], [2]]
# ['< start >', 'a', 'woman', 'kayaking', 'down', 'a', 'river', '', '< end >']
# [[3], [1], [20], [], [47], [1], [], [], [2]]
# ['< start >', 'a', 'woman', 'paddles', 'a', 'boat', 'down', 'a', 'river', '', '< end >']
# [[3], [1], [20], [], [1], [], [47], [1], [], [], [2]]
# ['< start >', 'a', 'woman', 'with', 'a', 'paddle', '', '< end >']
# [[3], [1], [20], [10], [1], [], [], [2]]
# ['< start >', 'a', 'woman', 'with', 'a', 'paddle', 'sits', 'in', 'a', 'boat', 'on', 'the', 'water', '', '< end >']
# [[3], [1], [20], [10], [1], [], [65], [4], [1], [], [6], [5], [24], [], [2]]
# ['< start >', 'a', 'girl', 'in', 'pigtails', 'splashes', 'in', 'the', 'shallow', 'water', '', '< end >']
# [[3], [1], [16], [4], [], [], [4], [5], [], [24], [], [2]]
# ['< start >', 'a', 'girls', 'plays', 'in', 'the', 'surf', '', '< end >']
# [[3], [1], [131], [89], [4], [5], [], [], [2]]
# ['< start >', 'a', 'girl', 'with', 'pigtails', 'is', 'playing', 'in', 'the', 'ocean', 'by', 'the', 'beach', '', '< end >']
# [[3], [1], [16], [10], [], [7], [29], [4], [5], [136], [55], [5], [36], [], [2]]
# ['< start >', 'a', 'girl', 'with', 'pigtails', 'plays', 'in', 'the', 'water', '', '< end >']
# [[3], [1], [16], [10], [], [89], [4], [5], [24], [], [2]]
# ['< start >', 'a', 'young', 'girl', 'in', 'pigtails', 'plays', 'in', 'the', 'water', '', '< end >']
# [[3], [1], [21], [16], [4], [], [89], [4], [5], [24], [], [2]]
# ['< start >', 'a', 'group', 'of', 'four', 'children', 'wearing', 'pajamas', 'have', 'a', 'pillow', 'fight', '', '< end >']
# [[3], [1], [81], [12], [132], [75], [31], [], [], [1], [], [], [], [2]]
# ['< start >', 'a', 'group', 'of', 'kids', 'have', 'a', 'pillow fight', '', '< end >']
# [[3], [1], [81], [12], [], [], [1], [], [], [2]]
# ['< start >', 'a', 'group', 'of', 'young', 'children', 'playing', 'pillow', 'fight', 'on', 'a', 'bed', '', '< end >']
# [[3], [1], [81], [12], [21], [75], [29], [], [], [6], [1], [121], [], [2]]
# ['< start >', 'children', 'having', 'a', 'pillow', 'fight', '', '< end >']
# [[3], [75], [], [1], [], [], [], [2]]
# ['< start >', 'four', 'children', 'are', 'having', 'a', 'pillow', 'fight', '', '< end >']
# [[3], [132], [75], [22], [], [1], [], [], [], [2]]
# ['< start >', 'two', 'constructions', 'workers', 'sit', 'on', 'a', 'beam', 'taking', 'a', 'break', '', '< end >']
# [[3], [13], [], [], [99], [6], [1], [], [], [1], [], [], [2]]
# ['< start >', 'two', 'construction', 'workers', 'are', 'sitting', 'up', 'on', 'the', 'side', 'of', 'a', 'building', '', '< end >']
# [[3], [13], [], [], [22], [39], [51], [6], [5], [104], [12], [1], [116], [], [2]]
# ['< start >', 'two', 'construction', 'workers', 'sitting', 'on', 'an', 'i beam', '', '< end >']
# [[3], [13], [], [], [39], [6], [26], [], [], [2]]
# ['< start >', 'two', 'construction', 'workers', 'take', 'a', 'seat', 'on', 'a', 'steel', 'beam', '', '< end >']
# [[3], [13], [], [], [], [1], [], [6], [1], [], [], [], [2]]
# ['< start >', 'two', 'men', 'take', 'a', 'break', 'from', 'construction', '', '< end >']
# [[3], [13], [82], [], [1], [], [84], [], [], [2]]
# ['< start >', 'the', 'children', 'are', 'playing', 'in', 'the', 'water', '', '< end >']
# [[3], [5], [75], [22], [29], [4], [5], [24], [], [2]]
# ['< start >', 'two', 'boys', '', 'one', 'with', 'a', 'yellow', 'and', 'orange', 'ball', '', 'play', 'in', 'some', 'water', 'in', 'front', 'of', 'a', 'field', '', '< end >']
# [[3], [13], [107], [], [70], [10], [1], [56], [8], [119], [50], [], [149], [4], [], [24], [4], [38], [12], [1], [45], [], [2]]
# ['< start >', 'two', 'boys', 'play', 'in', 'a', 'puddle', '', '< end >']
# [[3], [13], [107], [149], [4], [1], [], [], [2]]
# ['< start >', 'two', 'children', 'play', 'with', 'a', 'balloon', 'in', 'mud', 'on', 'a', 'sunny', 'day', '', '< end >']
# [[3], [13], [75], [149], [10], [1], [], [4], [], [6], [1], [], [], [], [2]]
# ['< start >', 'two', 'kids', 'are', 'running', 'and', 'playing', 'in', 'some', 'water', '', '< end >']
# [[3], [13], [], [22], [27], [8], [29], [4], [], [24], [], [2]]
# ['< start >', 'a', 'blond', 'woman', 'in', 'a', 'blue', 'shirt', 'appears', 'to', 'wait', 'for', 'a', 'ride', '', '< end >']
# [[3], [1], [152], [20], [4], [1], [28], [41], [], [23], [], [98], [1], [], [], [2]]
# ['< start >', 'a', 'blond', 'woman', 'is', 'on', 'the', 'street', 'hailing', 'a', 'taxi', '', '< end >']
# [[3], [1], [152], [20], [7], [6], [5], [60], [], [1], [], [], [2]]
# ['< start >', 'a', 'woman', 'is', 'signaling', 'is', 'to', 'traffic', '', 'as', 'seen', 'from', 'behind', '', '< end >']
# [[3], [1], [20], [7], [], [7], [23], [], [], [110], [], [84], [100], [], [2]]
# ['< start >', 'a', 'woman', 'with', 'blonde', 'hair', 'wearing', 'a', 'blue', 'tube', 'top', 'is', 'waving', 'on', 'the', 'side', 'of', 'the', 'street', '', '< end >']
# [[3], [1], [20], [10], [], [], [31], [1], [28], [], [], [7], [], [6], [5], [104], [12], [5], [60], [], [2]]
# ['< start >', 'the', 'woman', 'in', 'the', 'blue', 'dress', 'is', 'holding', 'out', 'her', 'arm', 'at', 'oncoming', 'traffic', '', '< end >']
# [[3], [5], [20], [4], [5], [28], [142], [7], [66], [87], [69], [], [15], [], [], [], [2]]
# ['< start >', 'a', 'little', 'girl', 'looking', 'at', 'a', 'brochure', 'on', 'train', 'rides', '< end >']
# [[3], [1], [32], [16], [108], [15], [1], [], [6], [], [88], [2]]
# ['< start >', 'a', 'young', 'blond', 'girl', 'with', 'a', 'magizine', 'in', 'her', 'hands', '< end >']
# [[3], [1], [21], [152], [16], [10], [1], [], [4], [69], [], [2]]
# ['< start >', 'a', 'young', 'girl', 'on', 'a', 'train', 'reads', 'a', 'book', 'about', 'train', 'rides', '', '< end >']
# [[3], [1], [21], [16], [6], [1], [], [], [1], [], [], [], [88], [], [2]]
# ['< start >', 'a', 'young', 'girl', 'sits', 'on', 'a', 'seat', 'and', 'looks', 'at', 'a', 'train', 'pamphlet', '', '< end >']
# [[3], [1], [21], [16], [65], [6], [1], [], [8], [126], [15], [1], [], [], [], [2]]
# ['< start >', 'child', 'sitting', 'down', 'looking', 'at', 'train', 'ride', 'brochure', '< end >']
# [[3], [30], [39], [47], [108], [15], [], [], [], [2]]
# ['< start >', 'a', 'brown', 'dog', 'is', 'running', 'after', 'a', 'black', 'dog', 'on', 'a', 'rocky', 'shore', '', '< end >']
# [[3], [1], [18], [9], [7], [27], [], [1], [17], [9], [6], [1], [], [143], [], [2]]
# ['< start >', 'a', 'brown', 'dog', 'is', 'running', 'after', 'the', 'black', 'dog', '', '< end >']
# [[3], [1], [18], [9], [7], [27], [], [5], [17], [9], [], [2]]
# ['< start >', 'two', 'dogs', 'playing', 'on', 'a', 'beach', '', '< end >']
# [[3], [13], [33], [29], [6], [1], [36], [], [2]]
# ['< start >', 'two', 'dogs', 'run', 'across', 'stones', 'near', 'a', 'body', 'of', 'water', '', '< end >']
# [[3], [13], [33], [], [], [], [57], [1], [], [12], [24], [], [2]]
# ['< start >', 'two', 'dogs', 'run', 'towards', 'each', 'other', 'on', 'a', 'rocky', 'area', 'with', 'water', 'in', 'the', 'background', '', '< end >']
# [[3], [13], [33], [], [], [117], [79], [6], [1], [], [], [10], [24], [4], [5], [], [], [2]]
# ['< start >', 'a', 'boy', 'descends', 'off', 'the', 'end', 'of', 'a', 'high', 'diving', 'board', '', '< end >']
# [[3], [1], [14], [], [76], [5], [2], [12], [1], [], [153], [], [], [2]]
# ['< start >', 'a', 'child', 'jumps', 'off', 'a', 'high', 'diving', 'board', 'into', 'the', 'pool', '', '< end >']
# [[3], [1], [30], [85], [76], [1], [], [153], [], [42], [5], [48], [], [2]]
# ['< start >', 'a', 'kid', 'jumps', 'off', 'the', 'diving', 'board', 'and', 'into', 'the', 'swimming', 'pool', 'below', '', '< end >']
# [[3], [1], [], [85], [76], [5], [153], [], [8], [42], [5], [101], [48], [], [], [2]]
# ['< start >', 'a', 'little', 'kid', 'is', 'jumping', 'off', 'a', 'high', 'dive', 'at', 'the', 'pool', '', '< end >']
# [[3], [1], [32], [], [7], [40], [76], [1], [], [], [15], [5], [48], [], [2]]
# ['< start >', 'the', 'boy', 'is', 'jumping', 'off', 'a', 'high', 'diving', 'board', 'into', 'the', 'pool', '', '< end >']
# [[3], [5], [14], [7], [40], [76], [1], [], [153], [], [42], [5], [48], [], [2]]
# ['< start >', 'a', 'guy', 'stands', 'by', 'a', 'window', 'taking', 'his', 'overshirt', 'off', '', '< end >']
# [[3], [1], [], [64], [55], [1], [], [], [35], [], [76], [], [2]]
# ['< start >', 'a', 'man', 'in', 'a', 'tank', 'top', 'stands', 'next', 'to', 'a', 'chrome', 'door', '', '< end >']
# [[3], [1], [11], [4], [1], [], [], [64], [68], [23], [1], [], [], [], [2]]
# ['< start >', 'a', 'man', 'puts', 'his', 'shirt', 'on', 'near', 'an', 'elevator', '', '< end >']
# [[3], [1], [11], [], [35], [41], [6], [57], [26], [], [], [2]]
# ['< start >', 'a', 'man', 'stands', 'by', 'an', 'elevator', 'with', 'his', 'head', 'down', '', '< end >']
# [[3], [1], [11], [64], [55], [26], [], [10], [35], [124], [47], [], [2]]
# ['< start >', 'the', 'man', 'is', 'putting', 'on', 'his', 'shirt', 'near', 'an', 'elevator', '', '< end >']
# [[3], [5], [11], [7], [], [6], [35], [41], [57], [26], [], [], [2]]
# ['< start >', 'a', 'light colored', 'dog', 'runs', 'on', 'the', 'beach', '', '< end >']
# [[3], [1], [], [9], [92], [6], [5], [36], [], [2]]
# ['< start >', 'a', 'small', 'yellow', 'dog', 'runs', 'on', 'a', 'beach', '< end >']
# [[3], [1], [46], [56], [9], [92], [6], [1], [36], [2]]
# ['< start >', 'a', 'tan', 'dog', 'runs', 'on', 'a', 'sandy', 'beach', '', '< end >']
# [[3], [1], [135], [9], [92], [6], [1], [], [36], [], [2]]
# ['< start >', 'a', 'white', 'dog', 'is', 'running', 'down', 'a', 'rocky', 'beach', '', '< end >']
# [[3], [1], [19], [9], [7], [27], [47], [1], [], [36], [], [2]]
# ['< start >', 'light', 'brown', 'dog', 'running', 'along', 'the', 'beach', '', '< end >']
# [[3], [], [18], [9], [27], [114], [5], [36], [], [2]]
# ['< start >', 'a', 'boy', 'in', 'his', 'blue', 'swim', 'shorts', 'at', 'the', 'beach', '', '< end >']
# [[3], [1], [14], [4], [35], [28], [], [94], [15], [5], [36], [], [2]]
# ['< start >', 'a', 'boy', 'smiles', 'for', 'the', 'camera', 'at', 'a', 'beach', '', '< end >']
# [[3], [1], [14], [], [98], [5], [86], [15], [1], [36], [], [2]]
# ['< start >', 'a', 'young', 'boy', 'in', 'swimming', 'trunks', 'is', 'walking', 'with', 'his', 'arms', 'outstretched', 'on', 'the', 'beach', '', '< end >']
# [[3], [1], [21], [14], [4], [101], [], [7], [77], [10], [35], [], [], [6], [5], [36], [], [2]]
# ['< start >', 'children', 'playing', 'on', 'the', 'beach', '', '< end >']
# [[3], [75], [29], [6], [5], [36], [], [2]]
# ['< start >', 'the', 'boy', 'is', 'playing', 'on', 'the', 'shore', 'of', 'an', 'ocean', '', '< end >']
# [[3], [5], [14], [7], [29], [6], [5], [143], [12], [26], [136], [], [2]]
# ['< start >', 'a', 'hiker', 'standing', 'high', 'on', 'a', 'bluff', 'overlooking', 'the', 'mountains', 'below', '', '< end >']
# [[3], [1], [], [53], [], [6], [1], [], [], [5], [], [], [], [2]]
# ['< start >', 'a', 'person', 'on', 'ski', "'s", 'looks', 'from', 'hill', 'over', 'snow', 'covered', 'landscape', '< end >']
# [[3], [1], [54], [6], [], [137], [126], [84], [120], [83], [59], [96], [], [2]]
# ['< start >', 'a', 'skier', 'is', 'overlooking', 'a', 'snow covered', 'mountain', '', '< end >']
# [[3], [1], [], [7], [], [1], [59, 96], [111], [], [2]]
# ['< start >', 'a', 'skier', 'is', 'overlooking', 'the', 'beautiful', 'white', 'snow', 'covered', 'landscape', '', '< end >']
# [[3], [1], [], [7], [], [5], [], [19], [59], [96], [], [], [2]]
# ['< start >', 'a', 'skier', 'pauses', 'on', 'a', 'mountaintop', '', '< end >']
# [[3], [1], [], [], [6], [1], [], [], [2]]
# ['< start >', 'a', 'black', 'and', 'white', 'dog', 'is', 'attempting', 'to', 'catch', 'a', 'yellow', 'and', 'purple', 'object', 'in', 'a', 'low', 'cut', 'yard', '', '< end >']
# ...
# [[3], [1], [11], [64], [68], [23], [1], [], [12], [], [], [], [], [2]]
# ['< start >', 'a', 'man', 'stands', 'next', 'to', 'three', 'video', 'game', 'machines', 'and', 'a', 'beer', 'sign', '', '< end >']
# [[3], [1], [11], [64], [68], [23], [43], [], [], [], [8], [1], [], [], [], [2]]
# ['< start >', 'a', 'man', 'stands', 'next', 'to', 'three', 'video', 'machines', '', '< end >']
# [[3], [1], [11], [64], [68], [23], [43], [], [], [], [2]]
# ['< start >', 'a', 'big', 'brown', 'dog', 'plays', 'with', 'a', 'smaller', 'grey', 'dog', 'on', 'the', 'grass', '', '< end >']
# [[3], [1], [], [18], [9], [89], [10], [1], [], [], [9], [6], [5], [49], [], [2]]
# ['< start >', 'the', 'dark', 'brown', 'dog', 'is', 'playing', 'with', 'the', 'light', 'brown', 'dog', '', '< end >']
# [[3], [5], [], [18], [9], [7], [29], [10], [5], [], [18], [9], [], [2]]
# ['< start >', 'two', 'brown', 'dogs', 'are', 'running', 'through', 'the', 'grass', '', '< end >']
# [[3], [13], [18], [33], [22], [27], [37], [5], [49], [], [2]]
# ['< start >', 'two', 'brown', 'dogs', 'run', 'side', 'by', 'side', '', '< end >']
# [[3], [13], [18], [33], [], [104], [55], [104], [], [2]]
# ['< start >', 'two', 'dogs', 'running', 'and', 'playing', 'rough', 'in', 'the', 'grass', '', '< end >']
# [[3], [13], [33], [27], [8], [29], [], [4], [5], [49], [], [2]]
# ['< start >', 'a', 'girl', 'in', 'blue', 'is', 'jumping', 'on', 'the', 'shore', 'as', 'small', 'waves', 'approach', 'her', '', '< end >']
# [[3], [1], [16], [4], [28], [7], [40], [6], [5], [143], [110], [46], [], [], [69], [], [2]]
# ['< start >', 'a', 'girl', 'leaps', 'into', 'the', 'air', 'while', 'standing', 'by', 'the', 'ocean', '', '< end >']
# [[3], [1], [16], [145], [42], [5], [67], [34], [53], [55], [5], [136], [], [2]]
# ['< start >', 'a', 'young', '', 'long haired', '', 'girl', 'on', 'the', 'beach', '', 'is', 'jumping', 'in', 'the', 'air', '', '< end >']
# [[3], [1], [21], [], [], [], [16], [6], [5], [36], [], [7], [40], [4], [5], [67], [], [2]]
# ['< start >', 'the', 'girl', 'is', 'running', 'into', 'the', 'ocean', 'from', 'the', 'shore', '', '< end >']
# [[3], [5], [16], [7], [27], [42], [5], [136], [84], [5], [143], [], [2]]
# ['< start >', 'the', 'girls', 'is', 'jumping', 'into', 'the', 'air', 'on', 'the', 'beach', '', '< end >']
# [[3], [5], [131], [7], [40], [42], [5], [67], [6], [5], [36], [], [2]]
# ['< start >', 'a', 'crowd', 'of', 'people', 'walk', 'down', 'a', 'busy', 'sidewalk', '', '< end >']
# [[3], [1], [], [12], [25], [], [47], [1], [154], [139], [], [2]]
# ['< start >', 'a', 'group', 'of', 'different', 'people', 'are', 'walking', 'in', 'all', 'different', 'directions', 'in', 'a', 'city', '', '< end >']
# [[3], [1], [81], [12], [], [25], [22], [77], [4], [], [], [], [4], [1], [125], [], [2]]
# ['< start >', 'a', 'group', 'of', 'people', 'walking', 'a', 'city', 'street', 'in', 'warm', 'weather', '', '< end >']
# [[3], [1], [81], [12], [25], [77], [1], [125], [60], [4], [], [], [], [2]]
# ['< start >', 'busy', 'intersection', 'in', 'the', 'summer', 'time', 'in', 'a', 'city', '< end >']
# [[3], [154], [], [4], [5], [], [], [4], [1], [125], [2]]
# ['< start >', 'people', 'in', 'summer', 'clothes', 'are', 'walking', 'on', 'the', 'sidewalk', 'of', 'a', 'large', 'city', '', '< end >']
# [[3], [25], [4], [], [], [22], [77], [6], [5], [139], [12], [1], [62], [125], [], [2]]
# ['< start >', 'a', 'big', 'dog', 'catches', 'a', 'ball', 'on', 'his', 'nose', '< end >']
# [[3], [1], [], [9], [], [1], [50], [6], [35], [], [2]]
# ['< start >', 'a', 'brown', 'and', 'black', 'dog', 'is', 'jumping', 'to', 'catch', 'a', 'red', 'ball', '', '< end >']
# [[3], [1], [18], [8], [17], [9], [7], [40], [23], [72], [1], [44], [50], [], [2]]
# ['< start >', 'a', 'brown', 'and', 'black', 'dog', 'jumps', 'for', 'a', 'red', 'ball', '', '< end >']
# [[3], [1], [18], [8], [17], [9], [85], [98], [1], [44], [50], [], [2]]
# ['< start >', 'dog', 'jumps', 'to', 'get', 'orange', 'ball', 'on', 'his', 'head', '', '< end >']
# [[3], [9], [85], [23], [], [119], [50], [6], [35], [124], [], [2]]
# ['< start >', 'the', 'brown', 'and', 'black', 'dog', 'is', 'jumping', 'up', 'to', 'catch', 'a', 'red', 'ball', '', '< end >']
# [[3], [5], [18], [8], [17], [9], [7], [40], [51], [23], [72], [1], [44], [50], [], [2]]
# ['< start >', 'two', 'blonde', 'boys', '', 'one', 'in', 'a', 'camouflage', 'shirt', 'and', 'the', 'other', 'in', 'blue', '', 'are', 'having', 'a', 'water', 'fight', '', '< end >']
# [[3], [13], [], [107], [], [70], [4], [1], [], [41], [8], [5], [79], [4], [28], [], [22], [], [1], [24], [], [], [2]]
# ['< start >', 'two', 'boys', 'are', 'squirting', 'water', 'guns', 'at', 'each', 'other', '', '< end >']
# [[3], [13], [107], [22], [], [24], [], [15], [117], [79], [], [2]]
# ['< start >', 'two', 'boys', 'spraying', 'each', 'other', 'with', 'water', '< end >']
# [[3], [13], [107], [], [117], [79], [10], [24], [2]]
# ['< start >', 'two', 'children', 'wearing', 'jeans', 'squirt', 'water', 'at', 'each', 'other', '', '< end >']
# [[3], [13], [75], [31], [], [], [24], [15], [117], [79], [], [2]]
# ['< start >', 'two', 'young', 'boys', 'are', 'squirting', 'water', 'at', 'each', 'other', '', '< end >']
# [[3], [13], [21], [107], [22], [], [24], [15], [117], [79], [], [2]]
# ['< start >', 'a', 'brown', 'dog', 'jumping', 'into', 'a', 'pool', 'after', 'a', 'bloe', 'ball', '', '< end >']
# [[3], [1], [18], [9], [40], [42], [1], [48], [], [1], [], [50], [], [2]]
# ['< start >', 'a', 'dog', 'in', 'the', 'air', 'above', 'the', 'swimming', 'pool', '', '< end >']
# [[3], [1], [9], [4], [5], [67], [], [5], [101], [48], [], [2]]
# ['< start >', 'a', 'dog', 'jumps', 'into', 'a', 'backyard', 'pool', '', '< end >']
# [[3], [1], [9], [85], [42], [1], [], [48], [], [2]]
# ['< start >', 'a', 'tan', 'colored', 'dog', 'is', 'jumping', 'into', 'an', 'outdoor', 'pool', '', '< end >']
# [[3], [1], [135], [], [9], [7], [40], [42], [26], [], [48], [], [2]]
# ['< start >', 'a', 'tan', 'colored', 'dog', 'leaps', 'into', 'the', 'inground', 'pool', '', '< end >']
# [[3], [1], [135], [], [9], [145], [42], [5], [], [48], [], [2]]
# ['< start >', 'parents', 'are', 'pushing', 'little', 'children', 'in', 'red', 'car', 'carts', '', '< end >']
# [[3], [], [22], [], [32], [75], [4], [44], [], [], [], [2]]
# ['< start >', 'twin', 'boys', 'being', 'pushed', 'in', 'small', 'car', 'shaped', 'strollers', 'in', 'a', 'parade', '< end >']
# [[3], [], [107], [], [], [4], [46], [], [], [], [4], [1], [], [2]]
# ['< start >', 'twin', 'toddlers', 'dressed', 'alike', 'being', 'pushed', 'in', 'plastic', 'car', 'strollers', 'in', 'a', 'parade', '< end >']
# [[3], [], [], [155], [], [], [], [4], [], [], [], [4], [1], [], [2]]
# ['< start >', 'two', 'children', 'ride', 'in', 'toy', 'cars', '', '< end >']
# [[3], [13], [75], [], [4], [52], [], [], [2]]
# ['< start >', 'two', 'kids', 'being', 'pushed', 'in', 'car', 'shaped', 'strollers', 'in', 'a', 'parade', '', '< end >']
# [[3], [13], [], [], [], [4], [], [], [], [4], [1], [], [], [2]]
# ['< start >', 'a', 'boys', 'baseball', 'team', 'wear', 'their', 'uniforms', '', '< end >']
# [[3], [1], [107], [], [], [], [129], [], [], [2]]
# ['< start >', 'a', 'small', 'boy', 'smiles', 'as', 'he', 'stands', 'with', 'others', 'wearing', 'the', 'same', 'black', 'hats', '', '< end >']
# [[3], [1], [46], [14], [], [110], [], [64], [10], [], [31], [5], [], [17], [], [], [2]]
# ['< start >', 'children', 'sporting', 'their', 'florida', 'dolphin', 'caps', '', '< end >']
# [[3], [75], [], [129], [], [], [], [], [2]]
# ['< start >', 'the', 'boys', 'are', 'all', 'wearing', 'the', 'same', 'baseball', 'hats', '', '< end >']
# [[3], [5], [107], [22], [], [31], [5], [], [], [], [], [2]]
# ['< start >', 'three', 'boys', 'wearing', 'florida', 'marlins', 'hats', '', '< end >']
# [[3], [43], [107], [31], [], [], [], [], [2]]
# ['< start >', 'a', 'brown', 'dog', 'running', 'through', 'the', 'grass', 'and', 'flowers', '', '< end >']
# [[3], [1], [18], [9], [27], [37], [5], [49], [8], [], [], [2]]
# ['< start >', 'a', 'dog', 'in', 'a', 'field', '', '< end >']
# [[3], [1], [9], [4], [1], [45], [], [2]]
# ['< start >', 'a', 'dog', 'running', 'in', 'a', 'field', 'of', 'grass', 'and', 'flowers', '', '< end >']
# [[3], [1], [9], [27], [4], [1], [45], [12], [49], [8], [], [], [2]]
# ['< start >', 'a', 'dog', 'running', 'in', 'shrubbery', 'along', 'a', 'stream', '', '< end >']
# [[3], [1], [9], [27], [4], [], [114], [1], [], [], [2]]
# ['< start >', 'a', 'dog', 'walks', 'through', 'a', 'field', '', '< end >']
# [[3], [1], [9], [106], [37], [1], [45], [], [2]]
# ['< start >', 'a', 'small', 'brown', 'and', 'black', 'dog', '< end >']
# [[3], [1], [46], [18], [8], [17], [9], [2]]
# ['< start >', 'a', 'small', 'brown', 'and', 'black', 'dog', 'playing', 'with', 'a', 'toy', '< end >']
# [[3], [1], [46], [18], [8], [17], [9], [29], [10], [1], [52], [2]]
# ['< start >', 'a', 'small', 'dog', 'plays', 'with', 'a', 'toy', 'on', 'top', 'of', 'a', 'white', 'blanket', '', '< end >']
# [[3], [1], [46], [9], [89], [10], [1], [52], [6], [], [12], [1], [19], [], [], [2]]
# ['< start >', 'a', 'small', '', 'shaggy', 'dog', 'playing', 'with', 'a', 'toy', 'on', 'a', 'blanket', '', '< end >']
# [[3], [1], [46], [], [], [9], [29], [10], [1], [52], [6], [1], [], [], [2]]
# ['< start >', 'terrier', 'dog', 'playing', 'with', 'toy', 'on', 'blanket', '< end >']
# [[3], [], [9], [29], [10], [52], [6], [], [2]]
# ['< start >', 'a', 'big', 'tan', 'dog', 'runs', 'on', 'grass', 'with', 'a', 'big', 'stick', 'in', 'his', 'mouth', '', '< end >']
# [[3], [1], [], [135], [9], [92], [6], [49], [10], [1], [], [], [4], [35], [74], [], [2]]
# ['< start >', 'a', 'dog', 'running', 'across', 'a', 'grassy', 'field', 'with', 'a', 'stick', 'in', 'its', 'mouth', '', '< end >']
# [[3], [1], [9], [27], [], [1], [109], [45], [10], [1], [], [4], [80], [74], [], [2]]
# ['< start >', 'a', 'dog', 'running', 'with', 'a', 'stick', 'in', 'his', 'mouth', '< end >']
# [[3], [1], [9], [27], [10], [1], [], [4], [35], [74], [2]]
# ['< start >', 'a', 'dog', 'runs', 'toward', 'the', 'camera', 'with', 'a', 'stick', 'in', 'its', 'mouth', '', '< end >']
# [[3], [1], [9], [92], [], [5], [86], [10], [1], [], [4], [80], [74], [], [2]]
# ['< start >', 'the', 'dog', 'carrying', 'a', 'long', 'stick', 'in', 'its', 'mouth', '', '< end >']
# [[3], [5], [9], [], [1], [], [], [4], [80], [74], [], [2]]
# ['< start >', 'a', 'dog', 'jumping', 'into', 'a', 'swimming', 'pool', '', '< end >']
# [[3], [1], [9], [40], [42], [1], [101], [48], [], [2]]
# ['< start >', 'a', 'grey', 'dog', 'runs', 'alongside', 'a', 'pool', 'while', 'a', 'yellow', 'dog', 'jumps', 'into', 'the', 'pool', '', '< end >']
# [[3], [1], [], [9], [92], [], [1], [48], [34], [1], [56], [9], [85], [42], [5], [48], [], [2]]
# ['< start >', 'one', 'dog', 'is', 'jumping', 'into', 'a', 'pool', 'while', 'another', 'runs', 'alongside', 'the', 'pool', "'s", 'edge', '', '< end >']
# [[3], [70], [9], [7], [40], [42], [1], [48], [34], [73], [92], [], [5], [48], [137], [], [], [2]]
# ['< start >', 'one', 'tan', 'dog', 'jumping', 'in', 'a', 'pool', 'while', 'the', 'other', 'grey', 'dog', 'is', 'on', 'the', 'deck', '< end >']
# [[3], [70], [135], [9], [40], [4], [1], [48], [34], [5], [79], [], [9], [7], [6], [5], [], [2]]
# ['< start >', 'two', 'dogs', 'jumping', 'into', 'a', 'swimming', 'pool', '', '< end >']
# [[3], [13], [33], [40], [42], [1], [101], [48], [], [2]]
# ['< start >', 'a', 'little', 'old', 'lady', 'sitting', 'next', 'to', 'an', 'advertisement', '', '< end >']
# [[3], [1], [32], [], [], [39], [68], [23], [26], [], [], [2]]
# ['< start >', 'an', 'asian', 'woman', 'waiting', 'at', 'an', 'underground', 'train', 'stop', '', '< end >']
# [[3], [26], [], [20], [], [15], [26], [], [], [], [], [2]]
# ['< start >', 'an', 'old', 'woman', 'sits', 'in', 'a', 'transit', 'station', 'next', 'to', 'a', 'backlit', 'advertisement', '', '< end >']
# [[3], [26], [], [20], [65], [4], [1], [], [], [68], [23], [1], [], [], [], [2]]
# ['< start >', 'a', 'woman', 'sits', 'in', 'a', 'subway', 'station', '', '< end >']
# [[3], [1], [20], [65], [4], [1], [], [], [], [2]]
# ['< start >', 'a', 'woman', 'with', 'an', 'umbrella', 'is', 'sitting', 'at', 'a', 'station', '', 'with', 'an', 'aquos', 'commercial', 'on', 'the', 'wall', '', '< end >']
# [[3], [1], [20], [10], [26], [], [7], [39], [15], [1], [], [], [10], [26], [], [], [6], [5], [93], [], [2]]
# ['< start >', 'a', 'girl', 'rides', 'a', 'unicycle', 'as', 'another', 'rides', 'a', 'scooter', 'next', 'to', 'her', '', '< end >']
# [[3], [1], [16], [88], [1], [], [110], [73], [88], [1], [], [68], [23], [69], [], [2]]
# ['< start >', 'a', 'girl', 'rides', 'a', 'unicycle', 'with', 'a', 'child', 'who', 'rides', 'a', 'scooter', '', '< end >']
# [[3], [1], [16], [88], [1], [], [10], [1], [30], [], [88], [1], [], [], [2]]
# ['< start >', 'a', 'young', 'girl', 'rides', 'a', 'unicycle', 'next', 'to', 'another', 'riding', 'a', 'scooter', 'on', 'a', 'busy', 'street', '', '< end >']
# [[3], [1], [21], [16], [88], [1], [], [68], [23], [73], [95], [1], [], [6], [1], [154], [60], [], [2]]
# ['< start >', 'the', 'girl', 'on', 'the', 'unicycle', 'reaches', 'out', 'for', 'the', 'child', 'on', 'the', 'scooter', '', '< end >']
# [[3], [5], [16], [6], [5], [], [], [87], [98], [5], [30], [6], [5], [], [], [2]]
# ['< start >', 'there', 'is', 'a', 'girl', 'on', 'a', 'unicycle', 'and', 'a', 'child', 'on', 'a', 'scooter', '', '< end >']
# [[3], [134], [7], [1], [16], [6], [1], [], [8], [1], [30], [6], [1], [], [], [2]]
# ['< start >', 'a', 'man', 'in', 'a', 'brown', 'shirt', 'sitting', 'on', 'a', 'dock', 'and', 'reading', '', '< end >']
# [[3], [1], [11], [4], [1], [18], [41], [39], [6], [1], [], [8], [], [], [2]]
# ['< start >', 'a', 'man', 'is', 'sitting', 'next', 'to', 'the', 'water', '', 'reading', '', '< end >']
# [[3], [1], [11], [7], [39], [68], [23], [5], [24], [], [], [], [2]]
# ['< start >', 'a', 'man', 'reading', 'a', 'book', 'on', 'the', 'dock', 'near', 'a', 'post', '', '< end >']
# [[3], [1], [11], [], [1], [], [6], [5], [], [57], [1], [], [], [2]]
# ['< start >', 'a', 'person', 'in', 'a', 'brown', 'jacket', 'is', 'sitting', 'on', 'a', 'pier', 'by', 'the', 'water', 'reading', '', '< end >']
# [[3], [1], [54], [4], [1], [18], [105], [7], [39], [6], [1], [], [55], [5], [24], [], [], [2]]
# ['< start >', 'person', 'sitting', 'on', 'concrete', 'landing', 'next', 'to', 'body', 'of', 'water', '< end >']
# [[3], [54], [39], [6], [], [], [68], [23], [], [12], [24], [2]]
# ['< start >', 'a', 'person', 'sits', 'at', 'a', 'table', 'behind', 'a', 'tree', '', '< end >']
# [[3], [1], [54], [65], [15], [1], [151], [100], [1], [], [], [2]]
# ['< start >', 'a', 'person', 'wearing', 'a', 'purple', 'jacket', 'stands', 'behind', 'a', 'tall', 'tree', '', '< end >']
# [[3], [1], [54], [31], [1], [], [105], [64], [100], [1], [], [], [], [2]]
# ['< start >', 'a', 'woman', 'in', 'a', 'purple', 'jacket', 'is', 'eating', 'a', 'snack', 'at', 'a', 'table', 'behind', 'the', 'tree', '', '< end >']
# [[3], [1], [20], [4], [1], [], [105], [7], [], [1], [], [15], [1], [151], [100], [5], [], [], [2]]
# ['< start >', 'a', 'woman', 'sits', 'at', 'a', 'picnic', 'table', 'eating', 'with', 'luggage', '', '< end >']
# [[3], [1], [20], [65], [15], [1], [], [151], [], [10], [], [], [2]]
# ['< start >', 'people', 'eat', 'under', 'green', 'trees', '', '< end >']
# [[3], [25], [], [], [63], [], [], [2]]
# ['< start >', 'a', 'couple', 'walking', 'along', 'on', 'a', 'sidewalk', '< end >']
# [[3], [1], [], [77], [114], [6], [1], [139], [2]]
# ['< start >', 'a', 'man', 'and', 'a', 'woman', 'walk', 'outside', '', '< end >']
# [[3], [1], [11], [8], [1], [20], [], [71], [], [2]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/52/80l4_7s57lb7fc5_j7qxm4zw0000gn/T/ipykernel_43850/3502037780.py in <module>
#       1 # get training data
#       2 train_data = create_training_data(train_image_captions, train_data_images, tokenizer, max_caption_len, vocab_len, 32)
# ----> 3 print("blah blah", next(train_data))
#       4 print("blah blah", next(train_data))
#       5 print("blah blah", next(train_data))
#
# TypeError: 'NoneType' object is not an iterator

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
# %matplotlib inline

# method for generating captions
def generate_captions(model, image, tokenizer, max_caption_length):
    # input is <start>
    input_text = '<start>'
    
    # keep generating words till we have encountered <end>
    for i in range(max_caption_length):
        seq = [tokenizer.word_index[w] for w in in_text.split() if w in list(tokenizer.word_index.keys())]
        seq = pad_sequences([sequence], maxlen=max_caption_length)
        prediction = model.predict([photo,sequence], verbose=0)
        prediction = np.argmax(prediction)
        word = tokenizer.index_word[prediction]
        input_text += ' ' + word
        if word == '<end>':
            break
    
    # remove <start> and <end> from output and return string
    output = in_text.split()
    output = output[1:-1]
    output = ' '.join(output)
    return output

# traverse through testing images to generate captions
count = 0
for key, value in test_data_images.items():
    test_image = test_data_images[key]
    test_image = np.expand_dims(test_image, axis=0)
    final_caption = generate_captions(predictive_model, test_image, tokenizer.word_index, max_caption_len, tokenizer.index_word)
    
    plt.figure(figsize=(7,7))
    image = Image.open(image_path + "//" + key + ".jpg")
    plt.imshow(image)
    plt.title(final_caption)
    
    count = count + 1
    if count == 3:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/52/80l4_7s57lb7fc5_j7qxm4zw0000gn/T/ipykernel_16239/3695666946.py in <module>
#      28 # traverse through testing images to generate captions
#      29 count = 0
# ---> 30 for key, value in test_image_features.items():
#      31     test_image = test_image_features[key]
#      32     test_image = np.expand_dims(test_image, axis=0)
#
# NameError: name 'test_image_features' is not defined
